# %%
# %cd ..
# Out:
# /home/mounim/PHD-Projects/GES

# %%
#pip install matplotlib numpy pandas seaborn

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.pyplot import figure
import seaborn as sns
import random
import sys
from itertools import combinations
import scipy.cluster.hierarchy as shc
from Bio.pairwise2 import format_alignment
from src import dataset_simulator
import networkx as nx
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from Bio import pairwise2
from Bio import Align

# %%
## Binary tree
### N generations
version = "binomial_dataset"
L = 100 # len of sequence
mutation_rate = 0.01
generations = 8 # N = g!
random_sequence = dataset_simulator.generate_random_seq(L) #sequence of lenght L
# make binary dataset 
simulated_dataset = dataset_simulator.make_binray_tree(random_sequence, generations = generations, mutation_rate = mutation_rate, mutation_types='S', distribution = 'binomial')

dataset_simulator.dict_to_fasta(simulated_dataset , './data/'+version+'/' , filename = version)

# %% [markdown]
# # TEST DATA

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
# simulated_dataset = predicted_dataset
 
# for end-node make childs


predicted_dataset = simulated_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())

vars_G6 = vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_G6.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_G6.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(2,3)
# Out:
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N12:  Gen2:N5
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen5:N31:  Gen4:N15
# Gen5:N33:  Gen4:N16
# Gen5:N35:  Gen4:N17
# Gen5:N36:  Gen4:N17
# Gen5:N37:  Gen4:N18
# Gen5:N38:  Gen4:N18
# Gen5:N39:  Gen4:N19
# Gen5:N40:  Gen4:N19
# Gen5:N41:  Gen4:N20
# Gen5:N42:  Gen4:N20
# Gen5:N43:  Gen4:N21
# Gen5:N44:  Gen4:N21
# Gen5:N45:  Gen4:N22
# Gen5:N46:  Gen4:N22
# Gen5:N47:  Gen4:N23
# Gen5:N49:  Gen4:N24
# Gen5:N50:  Gen4:N24
# Gen5:N51:  Gen4:N25
# Gen5:N52:  Gen4:N25
# Gen5:N54:  Gen4:N26
# Gen5:N55:  Gen4:N27
# Gen5:N56:  Gen4:N27
# Gen5:N57:  Gen4:N28
# Gen5:N59:  Gen4:N29
# Gen5:N60:  Gen4:N29
# Gen5:N61:  Gen4:N30
# Gen5:N62:  Gen4:N30
# Gen6:N63:  Gen5:N31
# Gen6:N64:  Gen5:N31
# Gen6:N66:  Gen5:N32
# Gen6:N67:  Gen5:N33
# Gen6:N68:  Gen5:N33
# Gen6:N70:  Gen5:N32
# Gen6:N71:  Gen5:N35
# Gen6:N72:  Gen5:N35
# Gen6:N73:  Gen5:N36
# Gen6:N74:  Gen5:N36
# Gen6:N75:  Gen5:N37
# Gen6:N76:  Gen5:N37
# Gen6:N77:  Gen4:N18
# Gen6:N78:  Gen5:N38
# Gen6:N79:  Gen5:N39
# Gen6:N80:  Gen5:N39
# Gen6:N81:  Gen5:N39
# Gen6:N82:  Gen5:N40
# Gen6:N83:  Gen5:N41
# Gen6:N84:  Gen5:N41
# Gen6:N85:  Gen5:N42
# Gen6:N86:  Gen5:N42
# Gen6:N87:  Gen5:N43
# Gen6:N89:  Gen5:N44
# Gen6:N90:  Gen5:N44
# Gen6:N91:  Gen5:N45
# Gen6:N92:  Gen5:N45
# Gen6:N94:  Gen5:N46
# Gen6:N95:  Gen5:N47
# Gen6:N96:  Gen5:N47
# Gen6:N98:  Gen3:N11
# Gen6:N99:  Gen5:N49
# Gen6:N100:  Gen5:N49
# Gen6:N101:  Gen5:N50
# Gen6:N102:  Gen5:N50
# Gen6:N103:  Gen5:N51
# Gen6:N104:  Gen5:N51
# Gen6:N106:  Gen5:N52
# Gen6:N107:  Gen5:N53
# Gen6:N108:  Gen5:N53
# Gen6:N109:  Gen5:N54
# Gen6:N110:  Gen5:N54
# Gen6:N111:  Gen5:N55
# Gen6:N112:  Gen5:N55
# Gen6:N113:  Gen5:N56
# Gen6:N114:  Gen5:N56
# Gen6:N115:  Gen5:N57
# Gen6:N116:  Gen5:N57
# Gen6:N117:  Gen3:N13
# Gen6:N118:  Gen3:N13
# Gen6:N119:  Gen5:N59
# Gen6:N120:  Gen5:N59
# Gen6:N121:  Gen5:N60
# Gen6:N123:  Gen5:N61
# Gen6:N124:  Gen5:N61
# Gen6:N125:  Gen5:N62
# Gen6:N126:  Gen5:N62
# Gen7:N127:  Gen6:N63
# Gen7:N128:  Gen6:N63
# Gen7:N129:  Gen6:N64
# Gen7:N130:  Gen6:N64
# Gen7:N131:  Gen6:N65
# Gen7:N133:  Gen6:N66
# Gen7:N134:  Gen6:N66
# Gen7:N135:  Gen6:N67
# Gen7:N136:  Gen4:N16
# Gen7:N137:  Gen6:N68
# Gen7:N138:  Gen6:N68
# Gen7:N139:  Gen6:N65
# Gen7:N140:  Gen4:N16
# Gen7:N141:  Gen6:N70
# Gen7:N142:  Gen6:N70
# Gen7:N143:  Gen6:N71
# Gen7:N144:  Gen6:N71
# Gen7:N145:  Gen6:N72
# Gen7:N146:  Gen6:N72
# Gen7:N147:  Gen6:N73
# Gen7:N148:  Gen6:N73
# Gen7:N149:  Gen6:N74
# Gen7:N150:  Gen6:N74
# Gen7:N151:  Gen6:N75
# Gen7:N152:  Gen6:N75
# Gen7:N153:  Gen6:N76
# Gen7:N154:  Gen6:N76
# Gen7:N155:  Gen6:N77
# Gen7:N156:  Gen6:N77
# Gen7:N157:  Gen6:N78
# Gen7:N158:  Gen6:N78
# Gen7:N159:  Gen6:N79
# Gen7:N160:  Gen6:N79
# Gen7:N161:  Gen6:N80
# Gen7:N162:  Gen6:N80
# Gen7:N163:  Gen6:N81
# Gen7:N164:  Gen6:N81
# Gen7:N165:  Gen6:N82
# Gen7:N166:  Gen6:N82
# Gen7:N167:  Gen6:N83
# Gen7:N168:  Gen6:N83
# Gen7:N169:  Gen6:N84
# Gen7:N170:  Gen6:N84
# Gen7:N171:  Gen6:N85
# Gen7:N172:  Gen6:N85
# Gen7:N173:  Gen6:N86
# Gen7:N174:  Gen6:N86
# Gen7:N175:  Gen6:N87
# Gen7:N176:  Gen6:N87
# Gen7:N177:  Gen6:N88
# Gen7:N178:  Gen6:N88
# Gen7:N179:  Gen6:N89
# Gen7:N180:  Gen6:N89
# Gen7:N181:  Gen5:N44
# Gen7:N182:  Gen6:N90
# Gen7:N183:  Gen6:N91
# Gen7:N184:  Gen6:N91
# Gen7:N185:  Gen6:N92
# Gen7:N186:  Gen6:N92
# Gen7:N187:  Gen4:N22
# Gen7:N188:  Gen4:N22
# Gen7:N189:  Gen6:N94
# Gen7:N190:  Gen6:N94
# Gen7:N191:  Gen6:N95
# Gen7:N192:  Gen6:N95
# Gen7:N193:  Gen6:N96
# Gen7:N194:  Gen6:N96
# Gen7:N195:  Gen4:N24
# Gen7:N196:  Gen6:N97
# Gen7:N197:  Gen6:N98
# Gen7:N198:  Gen6:N98
# Gen7:N199:  Gen6:N99
# Gen7:N200:  Gen6:N99
# Gen7:N201:  Gen6:N100
# Gen7:N202:  Gen6:N100
# Gen7:N203:  Gen6:N101
# Gen7:N204:  Gen6:N101
# Gen7:N205:  Gen6:N102
# Gen7:N206:  Gen6:N102
# Gen7:N207:  Gen6:N103
# Gen7:N208:  Gen6:N103
# Gen7:N211:  Gen6:N105
# Gen7:N212:  Gen6:N105
# Gen7:N213:  Gen6:N106
# Gen7:N214:  Gen6:N106
# Gen7:N215:  Gen6:N107
# Gen7:N216:  Gen6:N107
# Gen7:N218:  Gen6:N108
# Gen7:N219:  Gen6:N109
# Gen7:N220:  Gen6:N109
# Gen7:N221:  Gen6:N110
# Gen7:N222:  Gen6:N110
# Gen7:N223:  Gen6:N111
# Gen7:N224:  Gen6:N111
# Gen7:N225:  Gen6:N112
# Gen7:N226:  Gen6:N112
# Gen7:N227:  Gen6:N113
# Gen7:N228:  Gen6:N113
# Gen7:N229:  Gen6:N114
# Gen7:N230:  Gen6:N114
# Gen7:N231:  Gen6:N115
# Gen7:N232:  Gen6:N115
# Gen7:N233:  Gen6:N116
# Gen7:N234:  Gen6:N116
# Gen7:N235:  Gen2:N6
# Gen7:N236:  Gen6:N117
# Gen7:N237:  Gen6:N118
# Gen7:N238:  Gen6:N118
# Gen7:N239:  Gen6:N119
# Gen7:N240:  Gen6:N119
# Gen7:N241:  Gen6:N120
# Gen7:N242:  Gen6:N120
# Gen7:N243:  Gen6:N121
# Gen7:N244:  Gen6:N121
# Gen7:N245:  Gen6:N122
# Gen7:N246:  Gen6:N122
# Gen7:N247:  Gen6:N123
# Gen7:N248:  Gen6:N123
# Gen7:N249:  Gen6:N123
# Gen7:N250:  Gen6:N124
# Gen7:N251:  Gen6:N125
# Gen7:N252:  Gen4:N30
# Gen7:N253:  Gen6:N126
# Gen7:N254:  Gen4:N30
# Gen8:N255:  Gen7:N127
# Gen8:N256:  Gen6:N63
# Gen8:N257:  Gen7:N128
# Gen8:N258:  Gen7:N127
# Gen8:N259:  Gen7:N129
# Gen8:N260:  Gen7:N129
# Gen8:N261:  Gen7:N130
# Gen8:N262:  Gen7:N130
# Gen8:N263:  Gen7:N131
# Gen8:N264:  Gen7:N131
# Gen8:N265:  Gen5:N32
# Gen8:N266:  Gen5:N32
# Gen8:N267:  Gen7:N133
# Gen8:N268:  Gen7:N133
# Gen8:N269:  Gen7:N134
# Gen8:N270:  Gen7:N134
# Gen8:N271:  Gen7:N135
# Gen8:N272:  Gen7:N135
# Gen8:N273:  Gen7:N136
# Gen8:N274:  Gen4:N16
# Gen8:N275:  Gen7:N137
# Gen8:N276:  Gen7:N137
# Gen8:N277:  Gen7:N138
# Gen8:N278:  Gen7:N138
# Gen8:N279:  Gen7:N139
# Gen8:N280:  Gen7:N139
# Gen8:N281:  Gen7:N140
# Gen8:N282:  Gen7:N140
# Gen8:N283:  Gen7:N141
# Gen8:N284:  Gen7:N141
# Gen8:N285:  Gen7:N142
# Gen8:N286:  Gen7:N142
# Gen8:N287:  Gen7:N143
# Gen8:N288:  Gen7:N143
# Gen8:N289:  Gen7:N144
# Gen8:N290:  Gen7:N144
# Gen8:N291:  Gen7:N145
# Gen8:N292:  Gen7:N145
# Gen8:N293:  Gen7:N146
# Gen8:N294:  Gen6:N72
# Gen8:N295:  Gen7:N147
# Gen8:N296:  Gen7:N147
# Gen8:N297:  Gen7:N148
# Gen8:N298:  Gen7:N148
# Gen8:N299:  Gen7:N149
# Gen8:N300:  Gen7:N149
# Gen8:N301:  Gen7:N150
# Gen8:N302:  Gen7:N150
# Gen8:N303:  Gen7:N151
# Gen8:N304:  Gen7:N151
# Gen8:N305:  Gen5:N37
# Gen8:N306:  Gen7:N152
# Gen8:N307:  Gen7:N153
# Gen8:N308:  Gen7:N153
# Gen8:N309:  Gen7:N154
# Gen8:N310:  Gen7:N154
# Gen8:N311:  Gen7:N155
# Gen8:N312:  Gen7:N155
# Gen8:N313:  Gen7:N156
# Gen8:N314:  Gen7:N156
# Gen8:N315:  Gen7:N157
# Gen8:N316:  Gen7:N157
# Gen8:N317:  Gen7:N158
# Gen8:N318:  Gen7:N158
# Gen8:N319:  Gen7:N159
# Gen8:N320:  Gen7:N159
# Gen8:N321:  Gen7:N160
# Gen8:N322:  Gen7:N160
# Gen8:N323:  Gen7:N161
# Gen8:N324:  Gen7:N161
# Gen8:N325:  Gen7:N162
# Gen8:N326:  Gen7:N162
# Gen8:N327:  Gen7:N163
# Gen8:N328:  Gen7:N163
# Gen8:N329:  Gen7:N164
# Gen8:N330:  Gen7:N164
# Gen8:N331:  Gen7:N165
# Gen8:N332:  Gen7:N165
# Gen8:N333:  Gen7:N166
# Gen8:N334:  Gen7:N166
# Gen8:N335:  Gen7:N167
# Gen8:N336:  Gen7:N167
# Gen8:N337:  Gen7:N168
# Gen8:N338:  Gen7:N168
# Gen8:N339:  Gen6:N84
# Gen8:N340:  Gen7:N169
# Gen8:N341:  Gen7:N170
# Gen8:N342:  Gen7:N170
# Gen8:N343:  Gen7:N171
# Gen8:N344:  Gen7:N171
# Gen8:N345:  Gen7:N172
# Gen8:N346:  Gen7:N172
# Gen8:N347:  Gen7:N173
# Gen8:N348:  Gen5:N42
# Gen8:N349:  Gen7:N174
# Gen8:N350:  Gen7:N174
# Gen8:N351:  Gen7:N175
# Gen8:N352:  Gen7:N175
# Gen8:N353:  Gen7:N176
# Gen8:N354:  Gen7:N176
# Gen8:N355:  Gen7:N177
# Gen8:N356:  Gen7:N177
# Gen8:N357:  Gen7:N178
# Gen8:N359:  Gen7:N179
# Gen8:N360:  Gen7:N179
# Gen8:N361:  Gen7:N180
# Gen8:N362:  Gen7:N180
# Gen8:N363:  Gen7:N181
# Gen8:N364:  Gen7:N181
# Gen8:N365:  Gen7:N182
# Gen8:N366:  Gen7:N182
# Gen8:N367:  Gen7:N183
# Gen8:N368:  Gen7:N183
# Gen8:N369:  Gen7:N184
# Gen8:N370:  Gen7:N184
# Gen8:N371:  Gen7:N185
# Gen8:N372:  Gen7:N185
# Gen8:N373:  Gen7:N186
# Gen8:N374:  Gen7:N186
# Gen8:N375:  Gen4:N22
# Gen8:N376:  Gen7:N187
# Gen8:N377:  Gen7:N188
# Gen8:N378:  Gen7:N188
# Gen8:N379:  Gen7:N189
# Gen8:N380:  Gen7:N189
# Gen8:N381:  Gen7:N190
# Gen8:N382:  Gen7:N190
# Gen8:N383:  Gen7:N191
# Gen8:N384:  Gen7:N191
# Gen8:N385:  Gen5:N47
# Gen8:N386:  Gen6:N95
# Gen8:N387:  Gen7:N193
# Gen8:N388:  Gen5:N47
# Gen8:N389:  Gen7:N194
# Gen8:N390:  Gen7:N194
# Gen8:N391:  Gen7:N195
# Gen8:N393:  Gen7:N196
# Gen8:N394:  Gen7:N196
# Gen8:N395:  Gen7:N197
# Gen8:N396:  Gen7:N197
# Gen8:N397:  Gen7:N198
# Gen8:N398:  Gen7:N198
# Gen8:N399:  Gen7:N199
# Gen8:N400:  Gen7:N199
# Gen8:N403:  Gen7:N201
# Gen8:N404:  Gen7:N201
# Gen8:N405:  Gen7:N202
# Gen8:N406:  Gen7:N202
# Gen8:N407:  Gen7:N203
# Gen8:N408:  Gen7:N203
# Gen8:N409:  Gen7:N204
# Gen8:N410:  Gen7:N204
# Gen8:N411:  Gen7:N205
# Gen8:N412:  Gen7:N205
# Gen8:N413:  Gen7:N206
# Gen8:N414:  Gen7:N206
# Gen8:N415:  Gen7:N207
# Gen8:N416:  Gen7:N207
# Gen8:N417:  Gen7:N208
# Gen8:N418:  Gen7:N208
# Gen8:N419:  Gen7:N209
# Gen8:N420:  Gen7:N209
# Gen8:N421:  Gen7:N209
# Gen8:N422:  Gen7:N209
# Gen8:N423:  Gen7:N211
# Gen8:N425:  Gen7:N212
# Gen8:N426:  Gen7:N212
# Gen8:N427:  Gen7:N213
# Gen8:N428:  Gen7:N213
# Gen8:N429:  Gen7:N214
# Gen8:N430:  Gen7:N214
# Gen8:N431:  Gen7:N215
# Gen8:N432:  Gen7:N215
# Gen8:N433:  Gen7:N216
# Gen8:N434:  Gen7:N216
# Gen8:N435:  Gen5:N53
# Gen8:N436:  Gen3:N12
# Gen8:N437:  Gen7:N218
# Gen8:N438:  Gen7:N218
# Gen8:N439:  Gen7:N219
# Gen8:N440:  Gen7:N219
# Gen8:N441:  Gen7:N220
# Gen8:N442:  Gen7:N220
# Gen8:N443:  Gen7:N221
# Gen8:N444:  Gen7:N221
# Gen8:N445:  Gen7:N222
# Gen8:N446:  Gen7:N222
# Gen8:N447:  Gen7:N223
# Gen8:N448:  Gen7:N223
# Gen8:N449:  Gen7:N224
# Gen8:N450:  Gen7:N224
# Gen8:N451:  Gen7:N225
# Gen8:N452:  Gen7:N225
# Gen8:N453:  Gen7:N226
# Gen8:N454:  Gen7:N226
# Gen8:N455:  Gen7:N227
# Gen8:N456:  Gen7:N227
# Gen8:N457:  Gen7:N227
# Gen8:N458:  Gen7:N228
# Gen8:N459:  Gen6:N114
# Gen8:N460:  Gen7:N229
# Gen8:N461:  Gen7:N230
# Gen8:N462:  Gen7:N230
# Gen8:N463:  Gen7:N231
# Gen8:N464:  Gen7:N231
# Gen8:N465:  Gen7:N232
# Gen8:N466:  Gen7:N232
# Gen8:N467:  Gen7:N233
# Gen8:N468:  Gen7:N233
# Gen8:N469:  Gen7:N234
# Gen8:N470:  Gen6:N116
# Gen8:N471:  Gen7:N235
# Gen8:N472:  Gen7:N235
# Gen8:N473:  Gen7:N236
# Gen8:N474:  Gen7:N236
# Gen8:N475:  Gen7:N237
# Gen8:N476:  Gen7:N237
# Gen8:N477:  Gen7:N238
# Gen8:N478:  Gen7:N238
# Gen8:N479:  Gen7:N239
# Gen8:N480:  Gen7:N239
# Gen8:N481:  Gen7:N240
# Gen8:N482:  Gen7:N240
# Gen8:N483:  Gen7:N241
# Gen8:N484:  Gen7:N241
# Gen8:N485:  Gen7:N242
# Gen8:N486:  Gen7:N242
# Gen8:N487:  Gen7:N243
# Gen8:N488:  Gen7:N243
# Gen8:N489:  Gen7:N244
# Gen8:N490:  Gen7:N244
# Gen8:N491:  Gen7:N245
# Gen8:N493:  Gen7:N246
# Gen8:N494:  Gen7:N246
# Gen8:N495:  Gen7:N247
# Gen8:N496:  Gen7:N247
# Gen8:N497:  Gen5:N61
# Gen8:N498:  Gen7:N248
# Gen8:N499:  Gen6:N123
# Gen8:N500:  Gen7:N249
# Gen8:N501:  Gen7:N250
# Gen8:N502:  Gen7:N250
# Gen8:N503:  Gen7:N251
# Gen8:N504:  Gen7:N251
# Gen8:N505:  Gen6:N125
# Gen8:N506:  Gen7:N252
# Gen8:N507:  Gen6:N126
# Gen8:N508:  Gen7:N253
# Gen8:N509:  Gen7:N254
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# ...
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2338273375.py:127: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.9550275482093662
# (2.0, 3.0)

# %%
vars_test = vars_all

fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_test.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_test.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %% [markdown]
# ### NW Align

# %%
original_dataset = simulated_dataset
train_dataset = {}
test_dataset = {}
N_gen = 5
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G < N_gen:
        train_dataset[id] = simulated_dataset[id]
    else:
        test_dataset[id] = simulated_dataset[id]


# 1. pairwise align
path = './data/tmp/'

simulated_dataset = train_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])




names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])


import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        print(i + ": ", list(Y.columns))
        for c in list(Y.columns):
            edges.append([i, c])


Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id).split('N')[1]
    i+=1
id_map
edgelist = Edges.replace({0 : id_map, 1 : id_map} )
edgelist.columns = ['source','target']



fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


from sklearn import linear_model

# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()


vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')



mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

vars = vars_all
vars_G1 = vars_all
# Out:
# Gen0:N0:  ['Gen1:N1']
# Gen1:N1:  ['Gen0:N0']
# Gen1:N2:  ['Gen0:N0']
# Gen2:N3:  ['Gen1:N1']
# Gen2:N4:  ['Gen1:N1']
# Gen2:N5:  ['Gen1:N2']
# Gen2:N6:  ['Gen1:N2']
# Gen3:N7:  ['Gen2:N3']
# Gen3:N8:  ['Gen2:N3']
# Gen3:N9:  ['Gen2:N4']
# Gen3:N10:  ['Gen2:N4']
# Gen3:N11:  ['Gen2:N5']
# Gen3:N12:  ['Gen2:N5']
# Gen3:N13:  ['Gen2:N6']
# Gen3:N14:  ['Gen2:N6']
# Gen4:N15:  ['Gen3:N7']
# Gen4:N16:  ['Gen3:N7']
# Gen4:N17:  ['Gen1:N1']
# Gen4:N18:  ['Gen3:N8']
# Gen4:N19:  ['Gen3:N9']
# Gen4:N20:  ['Gen3:N9']
# Gen4:N21:  ['Gen3:N10']
# Gen4:N22:  ['Gen3:N10']
# Gen4:N23:  ['Gen3:N11']
# Gen4:N24:  ['Gen3:N11']
# Gen4:N25:  ['Gen2:N5']
# Gen4:N26:  ['Gen3:N12']
# Gen4:N27:  ['Gen3:N13']
# Gen4:N28:  ['Gen3:N13']
# Gen4:N29:  ['Gen3:N14']
# Gen4:N30:  ['Gen3:N14']
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1577463388.py:123: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)

# %%
vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
from Bio import pairwise2
from Bio import Align
import scipy
from scipy.stats import truncnorm

def get_truncated_normal(mean=0, sd=1, low=0, upp=10):
    return truncnorm(
        (low - mean) / sd, (upp - mean) / sd, loc=mean, scale=sd)

mut_rate = pd.concat( [mut_rate ,  pd.DataFrame({'x' : [0] , 'y' : [0]})] )

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
r = mut_rate_all.x  / mut_rate_all.y
N = round( r.mean() ) # N = number of mut per generation

new_dataset = {}
# define childs
# select seq from last generation to mutate
last_gen = 4
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G >= last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

Var = vars_all
di = dict({'A':0,'C':1,'G':2,'T':3, '-':4})
Var.ref = Var['ref'].map(di)
Var.tar = Var['tar'].map(di)
Var.pos = Var['pos']
X = Var[['ref','pos']]
y = Var[['tar']]


randomforest = RandomForestClassifier()
randomforest.fit(X, y)



def reverse_map(lst):
    new_list = []
    while len(lst):
        e = lst.pop()
        e = str(e).replace('0','A').replace('1','C').replace('2','G').replace('3','T')
        new_list.append(e)
    return new_list

mu, std = scipy.stats.norm.fit(np.array(vars_all['pos'], dtype=int) )
# Out:
# /tmp/ipykernel_3302156/64793630.py:39: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   randomforest.fit(X, y)

# %% [markdown]
# # Precit G +1

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
# simulated_dataset = predicted_dataset
simulated_dataset = train_dataset

last_gen = 4
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())

vars_G2 = vars_all

vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen4:N15
# Gen4:N16
# Gen4:N17
# Gen4:N18
# Gen4:N19
# Gen4:N20
# Gen4:N21
# Gen4:N22
# Gen4:N23
# Gen4:N24
# Gen4:N25
# Gen4:N26
# Gen4:N27
# Gen4:N28
# Gen4:N29
# Gen4:N30
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N1:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N2:  Gen4:N15
# Gen5:N3:  Gen4:N16
# Gen5:N3:  Gen4:N16
# Gen5:N3:  Gen4:N16
# Gen5:N3:  Gen4:N16
# Gen5:N4:  Gen4:N16
# Gen5:N5:  Gen4:N17
# Gen5:N6:  Gen1:N1
# Gen5:N7:  Gen4:N18
# Gen5:N8:  Gen4:N18
# Gen5:N9:  Gen4:N19
# Gen5:N10:  Gen4:N19
# Gen5:N11:  Gen4:N20
# Gen5:N12:  Gen4:N20
# Gen5:N13:  Gen4:N21
# Gen5:N14:  Gen4:N21
# Gen5:N15:  Gen4:N22
# Gen5:N16:  Gen3:N10
# Gen5:N17:  Gen4:N23
# Gen5:N18:  Gen4:N23
# Gen5:N19:  Gen4:N24
# Gen5:N20:  Gen4:N24
# Gen5:N21:  Gen4:N25
# Gen5:N22:  Gen4:N25
# Gen5:N23:  Gen4:N26
# Gen5:N24:  Gen4:N26
# Gen5:N25:  Gen4:N27
# Gen5:N26:  Gen4:N27
# Gen5:N27:  Gen4:N28
# Gen5:N28:  Gen4:N28
# Gen5:N29:  Gen4:N29
# Gen5:N30:  Gen4:N29
# Gen5:N31:  Gen4:N30
# Gen5:N32:  Gen4:N30
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1808333702.py:172: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.9718992248062016
# (0.0, 100.0)

# %% [markdown]
# # G +2

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
simulated_dataset = predicted_dataset

last_gen = 5
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())


vars_G3 = vars_all

vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen5:N1
# Gen5:N2
# Gen5:N3
# Gen5:N4
# Gen5:N5
# Gen5:N6
# Gen5:N7
# Gen5:N8
# Gen5:N9
# Gen5:N10
# Gen5:N11
# Gen5:N12
# Gen5:N13
# Gen5:N14
# Gen5:N15
# Gen5:N16
# Gen5:N17
# Gen5:N18
# Gen5:N19
# Gen5:N20
# Gen5:N21
# Gen5:N22
# Gen5:N23
# Gen5:N24
# Gen5:N25
# Gen5:N26
# Gen5:N27
# Gen5:N28
# Gen5:N29
# Gen5:N30
# Gen5:N31
# Gen5:N32
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N1:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N2:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N3:  Gen4:N15
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N4:  Gen6:N3
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N5:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N6:  Gen4:N16
# Gen6:N7:  Gen6:N8
# Gen6:N8:  Gen4:N16
# Gen6:N9:  Gen4:N17
# Gen6:N10:  Gen4:N17
# Gen6:N11:  Gen1:N1
# Gen6:N12:  Gen0:N0
# Gen6:N13:  Gen4:N18
# Gen6:N14:  Gen4:N18
# Gen6:N15:  Gen4:N18
# Gen6:N16:  Gen4:N18
# Gen6:N17:  Gen4:N19
# Gen6:N18:  Gen4:N19
# Gen6:N19:  Gen4:N19
# Gen6:N20:  Gen4:N19
# Gen6:N21:  Gen4:N20
# Gen6:N22:  Gen4:N20
# Gen6:N23:  Gen6:N24
# Gen6:N24:  Gen4:N20
# Gen6:N25:  Gen6:N26
# Gen6:N26:  Gen4:N21
# Gen6:N27:  Gen4:N21
# Gen6:N28:  Gen4:N21
# Gen6:N29:  Gen4:N22
# Gen6:N30:  Gen4:N22
# Gen6:N31:  Gen3:N10
# Gen6:N32:  Gen3:N10
# Gen6:N33:  Gen4:N23
# Gen6:N34:  Gen6:N33
# Gen6:N35:  Gen6:N36
# Gen6:N36:  Gen4:N23
# Gen6:N41:  Gen4:N25
# Gen6:N42:  Gen4:N25
# Gen6:N43:  Gen3:N11
# Gen6:N44:  Gen4:N25
# Gen6:N45:  Gen6:N46
# Gen6:N46:  Gen4:N26
# Gen6:N47:  Gen4:N26
# Gen6:N48:  Gen4:N26
# Gen6:N49:  Gen4:N27
# Gen6:N50:  Gen4:N27
# Gen6:N51:  Gen4:N27
# Gen6:N52:  Gen4:N27
# Gen6:N53:  Gen4:N28
# Gen6:N54:  Gen4:N28
# Gen6:N55:  Gen4:N28
# Gen6:N56:  Gen6:N55
# Gen6:N57:  Gen4:N29
# Gen6:N58:  Gen4:N29
# Gen6:N59:  Gen4:N29
# Gen6:N60:  Gen6:N59
# Gen6:N61:  Gen4:N30
# Gen6:N62:  Gen4:N30
# Gen6:N63:  Gen4:N30
# Gen6:N64:  Gen4:N30
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/4289826748.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.9393700787401577
# (0.0, 100.0)

# %% [markdown]
# # GEN ++3

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
simulated_dataset = predicted_dataset

last_gen = 6
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())


vars_G4 = vars_all

vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen6:N1
# Gen6:N2
# Gen6:N3
# Gen6:N4
# Gen6:N5
# Gen6:N6
# Gen6:N7
# Gen6:N8
# Gen6:N9
# Gen6:N10
# Gen6:N11
# Gen6:N12
# Gen6:N13
# Gen6:N14
# Gen6:N15
# Gen6:N16
# Gen6:N17
# Gen6:N18
# Gen6:N19
# Gen6:N20
# Gen6:N21
# Gen6:N22
# Gen6:N23
# Gen6:N24
# Gen6:N25
# Gen6:N26
# Gen6:N27
# Gen6:N28
# Gen6:N29
# Gen6:N30
# Gen6:N31
# Gen6:N32
# Gen6:N33
# Gen6:N34
# Gen6:N35
# Gen6:N36
# Gen6:N37
# Gen6:N38
# Gen6:N39
# Gen6:N40
# Gen6:N41
# Gen6:N42
# Gen6:N43
# Gen6:N44
# Gen6:N45
# Gen6:N46
# Gen6:N47
# Gen6:N48
# Gen6:N49
# Gen6:N50
# Gen6:N51
# Gen6:N52
# Gen6:N53
# Gen6:N54
# Gen6:N55
# Gen6:N56
# Gen6:N57
# Gen6:N58
# Gen6:N59
# Gen6:N60
# Gen6:N61
# Gen6:N62
# Gen6:N63
# Gen6:N64
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N1:  Gen7:N2
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N2:  Gen7:N1
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N3:  Gen7:N4
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N4:  Gen7:N3
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N5:  Gen4:N15
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N6:  Gen7:N7
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N7:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N8:  Gen7:N6
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N9:  Gen7:N10
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N10:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N11:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N12:  Gen7:N9
# Gen7:N13:  Gen7:N16
# Gen7:N14:  Gen7:N16
# Gen7:N15:  Gen4:N16
# Gen7:N16:  Gen7:N13
# Gen7:N17:  Gen7:N18
# Gen7:N18:  Gen7:N17
# Gen7:N19:  Gen7:N20
# Gen7:N20:  Gen7:N19
# Gen7:N21:  Gen7:N22
# Gen7:N22:  Gen7:N21
# Gen7:N23:  Gen0:N0
# Gen7:N24:  Gen0:N0
# Gen7:N25:  Gen7:N26
# Gen7:N26:  Gen7:N25
# Gen7:N27:  Gen4:N18
# Gen7:N28:  Gen7:N27
# Gen7:N29:  Gen7:N30
# Gen7:N30:  Gen7:N29
# Gen7:N31:  Gen7:N21
# Gen7:N32:  Gen7:N31
# Gen7:N33:  Gen7:N34
# Gen7:N34:  Gen7:N33
# Gen7:N37:  Gen7:N35
# Gen7:N38:  Gen4:N19
# Gen7:N39:  Gen4:N19
# Gen7:N40:  Gen7:N39
# Gen7:N41:  Gen7:N42
# Gen7:N42:  Gen7:N41
# Gen7:N43:  Gen7:N44
# Gen7:N44:  Gen4:N20
# Gen7:N45:  Gen7:N46
# Gen7:N46:  Gen7:N45
# Gen7:N47:  Gen4:N20
# Gen7:N48:  Gen7:N47
# Gen7:N49:  Gen7:N50
# Gen7:N50:  Gen7:N49
# Gen7:N51:  Gen4:N21
# Gen7:N52:  Gen4:N21
# Gen7:N53:  Gen7:N54
# Gen7:N54:  Gen7:N53
# Gen7:N55:  Gen7:N56
# Gen7:N56:  Gen7:N54
# Gen7:N57:  Gen7:N58
# Gen7:N58:  Gen7:N57
# Gen7:N59:  Gen7:N60
# Gen7:N60:  Gen7:N59
# Gen7:N63:  Gen7:N51
# Gen7:N64:  Gen7:N63
# Gen7:N65:  Gen4:N23
# Gen7:N66:  Gen4:N23
# Gen7:N67:  Gen7:N68
# Gen7:N68:  Gen7:N67
# Gen7:N69:  Gen7:N70
# Gen7:N70:  Gen7:N69
# Gen7:N71:  Gen4:N23
# Gen7:N72:  Gen4:N23
# Gen7:N73:  Gen4:N24
# Gen7:N74:  Gen4:N24
# Gen7:N75:  Gen4:N24
# Gen7:N76:  Gen3:N11
# Gen7:N77:  Gen7:N78
# Gen7:N78:  Gen7:N77
# Gen7:N79:  Gen7:N77
# Gen7:N80:  Gen7:N77
# Gen7:N83:  Gen7:N84
# Gen7:N84:  Gen7:N83
# Gen7:N85:  Gen3:N11
# Gen7:N86:  Gen7:N72
# Gen7:N87:  Gen7:N88
# Gen7:N88:  Gen7:N87
# Gen7:N89:  Gen7:N90
# Gen7:N90:  Gen7:N89
# Gen7:N91:  Gen7:N92
# Gen7:N92:  Gen4:N26
# Gen7:N93:  Gen7:N94
# Gen7:N94:  Gen7:N93
# Gen7:N95:  Gen7:N96
# Gen7:N96:  Gen7:N93
# Gen7:N97:  Gen7:N99
# Gen7:N98:  Gen7:N97
# Gen7:N99:  Gen7:N97
# Gen7:N100:  Gen7:N99
# Gen7:N101:  Gen7:N102
# Gen7:N102:  Gen7:N101
# Gen7:N103:  Gen7:N104
# Gen7:N104:  Gen7:N103
# Gen7:N105:  Gen7:N106
# Gen7:N106:  Gen7:N105
# Gen7:N107:  Gen7:N108
# Gen7:N108:  Gen7:N107
# Gen7:N109:  Gen3:N13
# Gen7:N110:  Gen4:N28
# Gen7:N111:  Gen7:N112
# Gen7:N112:  Gen7:N111
# Gen7:N113:  Gen7:N114
# Gen7:N114:  Gen7:N113
# Gen7:N115:  Gen7:N116
# Gen7:N116:  Gen7:N115
# Gen7:N117:  Gen4:N29
# Gen7:N118:  Gen4:N29
# Gen7:N119:  Gen7:N120
# Gen7:N120:  Gen7:N119
# Gen7:N121:  Gen7:N124
# Gen7:N122:  Gen7:N121
# Gen7:N123:  Gen7:N124
# Gen7:N124:  Gen7:N121
# Gen7:N125:  Gen7:N126
# Gen7:N126:  Gen7:N125
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/1001473458.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.8053751803751805
# (0.0, 100.0)

# %% [markdown]
# # G +3

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
simulated_dataset = predicted_dataset

last_gen = 7
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())


vars_G5 = vars_all



vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen7:N1
# Gen7:N2
# Gen7:N3
# Gen7:N4
# Gen7:N5
# Gen7:N6
# Gen7:N7
# Gen7:N8
# Gen7:N9
# Gen7:N10
# Gen7:N11
# Gen7:N12
# Gen7:N13
# Gen7:N14
# Gen7:N15
# Gen7:N16
# Gen7:N17
# Gen7:N18
# Gen7:N19
# Gen7:N20
# Gen7:N21
# Gen7:N22
# Gen7:N23
# Gen7:N24
# Gen7:N25
# Gen7:N26
# Gen7:N27
# Gen7:N28
# Gen7:N29
# Gen7:N30
# Gen7:N31
# Gen7:N32
# Gen7:N33
# Gen7:N34
# Gen7:N35
# Gen7:N36
# Gen7:N37
# Gen7:N38
# Gen7:N39
# Gen7:N40
# Gen7:N41
# Gen7:N42
# Gen7:N43
# Gen7:N44
# Gen7:N45
# Gen7:N46
# Gen7:N47
# Gen7:N48
# Gen7:N49
# Gen7:N50
# Gen7:N51
# Gen7:N52
# Gen7:N53
# Gen7:N54
# Gen7:N55
# Gen7:N56
# Gen7:N57
# Gen7:N58
# Gen7:N59
# Gen7:N60
# Gen7:N61
# Gen7:N62
# Gen7:N63
# Gen7:N64
# Gen7:N65
# Gen7:N66
# Gen7:N67
# Gen7:N68
# Gen7:N69
# Gen7:N70
# Gen7:N71
# Gen7:N72
# Gen7:N73
# Gen7:N74
# Gen7:N75
# Gen7:N76
# Gen7:N77
# Gen7:N78
# Gen7:N79
# Gen7:N80
# Gen7:N81
# Gen7:N82
# Gen7:N83
# Gen7:N84
# Gen7:N85
# Gen7:N86
# Gen7:N87
# Gen7:N88
# Gen7:N89
# Gen7:N90
# Gen7:N91
# Gen7:N92
# Gen7:N93
# Gen7:N94
# Gen7:N95
# Gen7:N96
# Gen7:N97
# Gen7:N98
# Gen7:N99
# Gen7:N100
# Gen7:N101
# Gen7:N102
# Gen7:N103
# Gen7:N104
# Gen7:N105
# Gen7:N106
# Gen7:N107
# Gen7:N108
# Gen7:N109
# Gen7:N110
# Gen7:N111
# Gen7:N112
# Gen7:N113
# Gen7:N114
# Gen7:N115
# Gen7:N116
# Gen7:N117
# Gen7:N118
# Gen7:N119
# Gen7:N120
# Gen7:N121
# Gen7:N122
# Gen7:N123
# Gen7:N124
# Gen7:N125
# Gen7:N126
# Gen7:N127
# Gen7:N128
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N1:  Gen8:N2
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N2:  Gen8:N1
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N3:  Gen8:N4
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N4:  Gen8:N3
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N5:  Gen8:N8
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N6:  Gen8:N5
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N7:  Gen8:N6
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N8:  Gen8:N5
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N9:  Gen8:N10
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N10:  Gen8:N9
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N11:  Gen8:N14
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N12:  Gen8:N9
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N13:  Gen8:N14
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N14:  Gen8:N11
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N15:  Gen8:N16
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N16:  Gen8:N15
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N17:  Gen8:N18
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N18:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N19:  Gen8:N20
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N20:  Gen8:N18
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N21:  Gen8:N22
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N22:  Gen8:N18
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N23:  Gen8:N24
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N24:  Gen8:N21
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N25:  Gen8:N26
# Gen8:N26:  Gen8:N25
# Gen8:N27:  Gen8:N28
# Gen8:N28:  Gen8:N27
# Gen8:N29:  Gen8:N30
# Gen8:N30:  Gen8:N29
# Gen8:N31:  Gen8:N32
# Gen8:N32:  Gen8:N31
# Gen8:N33:  Gen8:N34
# Gen8:N34:  Gen8:N33
# Gen8:N35:  Gen8:N36
# Gen8:N36:  Gen8:N5
# Gen8:N37:  Gen8:N38
# Gen8:N39:  Gen8:N38
# Gen8:N41:  Gen8:N43
# Gen8:N42:  Gen8:N41
# Gen8:N43:  Gen8:N41
# Gen8:N44:  Gen8:N43
# Gen8:N45:  Gen8:N46
# Gen8:N46:  Gen8:N45
# Gen8:N47:  Gen8:N48
# Gen8:N48:  Gen8:N47
# Gen8:N49:  Gen8:N50
# Gen8:N50:  Gen8:N49
# Gen8:N51:  Gen8:N52
# Gen8:N52:  Gen8:N51
# Gen8:N53:  Gen8:N54
# Gen8:N54:  Gen8:N53
# Gen8:N55:  Gen8:N56
# Gen8:N56:  Gen8:N55
# Gen8:N57:  Gen8:N58
# Gen8:N58:  Gen8:N57
# Gen8:N59:  Gen8:N57
# Gen8:N60:  Gen8:N58
# Gen8:N61:  Gen8:N62
# Gen8:N62:  Gen8:N61
# Gen8:N63:  Gen8:N64
# Gen8:N64:  Gen8:N36
# Gen8:N65:  Gen8:N66
# Gen8:N66:  Gen8:N65
# Gen8:N67:  Gen8:N68
# Gen8:N68:  Gen8:N66
# Gen8:N69:  Gen8:N66
# Gen8:N70:  Gen8:N69
# Gen8:N71:  Gen8:N69
# Gen8:N72:  Gen8:N69
# Gen8:N73:  Gen8:N74
# Gen8:N74:  Gen8:N73
# Gen8:N75:  Gen8:N76
# Gen8:N76:  Gen8:N74
# Gen8:N79:  Gen8:N80
# Gen8:N80:  Gen8:N79
# Gen8:N81:  Gen8:N82
# Gen8:N82:  Gen8:N81
# Gen8:N85:  Gen8:N86
# Gen8:N86:  Gen8:N85
# Gen8:N87:  Gen8:N88
# Gen8:N88:  Gen8:N86
# Gen8:N91:  Gen8:N92
# Gen8:N92:  Gen8:N45
# Gen8:N93:  Gen4:N20
# Gen8:N94:  Gen4:N20
# Gen8:N95:  Gen8:N96
# Gen8:N96:  Gen8:N87
# Gen8:N97:  Gen8:N98
# Gen8:N98:  Gen8:N97
# Gen8:N99:  Gen8:N100
# Gen8:N100:  Gen8:N99
# Gen8:N101:  Gen8:N102
# Gen8:N102:  Gen8:N101
# Gen8:N103:  Gen8:N104
# Gen8:N104:  Gen8:N103
# Gen8:N105:  Gen8:N106
# Gen8:N106:  Gen8:N105
# Gen8:N107:  Gen8:N108
# Gen8:N108:  Gen8:N107
# Gen8:N111:  Gen8:N112
# Gen8:N112:  Gen8:N111
# Gen8:N113:  Gen8:N114
# Gen8:N114:  Gen8:N113
# Gen8:N115:  Gen8:N116
# Gen8:N116:  Gen8:N115
# Gen8:N117:  Gen8:N118
# Gen8:N118:  Gen8:N117
# Gen8:N119:  Gen8:N120
# Gen8:N120:  Gen8:N117
# Gen8:N121:  Gen8:N123
# Gen8:N122:  Gen8:N123
# Gen8:N125:  Gen8:N126
# Gen8:N126:  Gen8:N125
# Gen8:N127:  Gen8:N128
# Gen8:N128:  Gen8:N127
# Gen8:N129:  Gen8:N130
# Gen8:N130:  Gen8:N129
# Gen8:N131:  Gen8:N149
# Gen8:N132:  Gen8:N131
# Gen8:N133:  Gen8:N134
# Gen8:N134:  Gen8:N133
# Gen8:N135:  Gen8:N136
# Gen8:N136:  Gen8:N135
# Gen8:N137:  Gen8:N138
# Gen8:N138:  Gen8:N137
# Gen8:N139:  Gen8:N140
# Gen8:N140:  Gen8:N139
# Gen8:N141:  Gen8:N142
# Gen8:N142:  Gen8:N141
# Gen8:N143:  Gen8:N144
# Gen8:N144:  Gen8:N143
# Gen8:N145:  Gen8:N146
# Gen8:N146:  Gen8:N145
# Gen8:N147:  Gen8:N148
# Gen8:N148:  Gen8:N147
# Gen8:N149:  Gen8:N131
# Gen8:N150:  Gen4:N24
# Gen8:N151:  Gen8:N152
# Gen8:N152:  Gen8:N148
# Gen8:N153:  Gen8:N154
# Gen8:N154:  Gen8:N153
# Gen8:N155:  Gen8:N156
# Gen8:N156:  Gen8:N155
# Gen8:N157:  Gen8:N158
# Gen8:N158:  Gen8:N153
# Gen8:N159:  Gen8:N158
# Gen8:N160:  Gen8:N158
# Gen8:N161:  Gen8:N162
# Gen8:N162:  Gen8:N161
# Gen8:N163:  Gen8:N161
# Gen8:N164:  Gen8:N161
# Gen8:N165:  Gen8:N166
# Gen8:N166:  Gen8:N165
# Gen8:N167:  Gen8:N168
# Gen8:N168:  Gen8:N167
# Gen8:N169:  Gen3:N11
# Gen8:N170:  Gen8:N169
# Gen8:N171:  Gen8:N172
# Gen8:N172:  Gen8:N170
# Gen8:N173:  Gen8:N174
# Gen8:N174:  Gen8:N173
# Gen8:N175:  Gen8:N176
# Gen8:N176:  Gen8:N175
# Gen8:N177:  Gen8:N178
# Gen8:N178:  Gen8:N177
# Gen8:N179:  Gen8:N180
# Gen8:N180:  Gen8:N179
# Gen8:N181:  Gen8:N182
# Gen8:N182:  Gen8:N181
# Gen8:N183:  Gen8:N184
# Gen8:N184:  Gen4:N26
# Gen8:N185:  Gen8:N186
# Gen8:N186:  Gen8:N189
# Gen8:N187:  Gen8:N188
# Gen8:N188:  Gen8:N187
# Gen8:N189:  Gen8:N186
# Gen8:N190:  Gen8:N189
# Gen8:N191:  Gen8:N192
# Gen8:N192:  Gen8:N188
# Gen8:N193:  Gen8:N194
# Gen8:N194:  Gen8:N193
# Gen8:N195:  Gen8:N196
# Gen8:N196:  Gen8:N195
# Gen8:N197:  Gen8:N200
# Gen8:N198:  Gen8:N197
# Gen8:N199:  Gen8:N194
# Gen8:N200:  Gen8:N197
# Gen8:N205:  Gen8:N206
# Gen8:N206:  Gen8:N205
# Gen8:N207:  Gen8:N208
# Gen8:N208:  Gen8:N206
# Gen8:N209:  Gen8:N210
# Gen8:N210:  Gen8:N209
# Gen8:N211:  Gen8:N212
# Gen8:N212:  Gen8:N211
# Gen8:N213:  Gen8:N214
# Gen8:N216:  Gen8:N214
# Gen8:N217:  Gen8:N218
# Gen8:N218:  Gen8:N217
# Gen8:N219:  Gen8:N220
# Gen8:N220:  Gen8:N219
# Gen8:N221:  Gen8:N222
# Gen8:N222:  Gen8:N221
# Gen8:N223:  Gen8:N224
# Gen8:N224:  Gen8:N223
# Gen8:N225:  Gen8:N226
# Gen8:N226:  Gen8:N225
# Gen8:N227:  Gen8:N225
# Gen8:N228:  Gen8:N226
# Gen8:N233:  Gen8:N234
# Gen8:N234:  Gen8:N233
# Gen8:N235:  Gen8:N236
# Gen8:N236:  Gen8:N235
# Gen8:N242:  Gen8:N241
# Gen8:N243:  Gen8:N244
# Gen8:N244:  Gen8:N243
# Gen8:N245:  Gen8:N246
# Gen8:N246:  Gen8:N245
# Gen8:N248:  Gen8:N241
# Gen8:N249:  Gen8:N226
# Gen8:N250:  Gen8:N249
# Gen8:N251:  Gen8:N252
# Gen8:N252:  Gen8:N251
# Gen8:N255:  Gen8:N253
# Gen8:N256:  Gen8:N253
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2650552459.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.8759259259259259
# (0.0, 100.0)

# %% [markdown]
# # G +4

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
simulated_dataset = predicted_dataset

last_gen = 8
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())



vars_all
vars_G6 = vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen8:N1
# Gen8:N2
# Gen8:N3
# Gen8:N4
# Gen8:N5
# Gen8:N6
# Gen8:N7
# Gen8:N8
# Gen8:N9
# Gen8:N10
# Gen8:N11
# Gen8:N12
# Gen8:N13
# Gen8:N14
# Gen8:N15
# Gen8:N16
# Gen8:N17
# Gen8:N18
# Gen8:N19
# Gen8:N20
# Gen8:N21
# Gen8:N22
# Gen8:N23
# Gen8:N24
# Gen8:N25
# Gen8:N26
# Gen8:N27
# Gen8:N28
# Gen8:N29
# Gen8:N30
# Gen8:N31
# Gen8:N32
# Gen8:N33
# Gen8:N34
# Gen8:N35
# Gen8:N36
# Gen8:N37
# Gen8:N38
# Gen8:N39
# Gen8:N40
# Gen8:N41
# Gen8:N42
# Gen8:N43
# Gen8:N44
# Gen8:N45
# Gen8:N46
# Gen8:N47
# Gen8:N48
# Gen8:N49
# Gen8:N50
# Gen8:N51
# Gen8:N52
# Gen8:N53
# Gen8:N54
# Gen8:N55
# Gen8:N56
# Gen8:N57
# Gen8:N58
# Gen8:N59
# Gen8:N60
# Gen8:N61
# Gen8:N62
# Gen8:N63
# Gen8:N64
# Gen8:N65
# Gen8:N66
# Gen8:N67
# Gen8:N68
# Gen8:N69
# Gen8:N70
# Gen8:N71
# Gen8:N72
# Gen8:N73
# Gen8:N74
# Gen8:N75
# Gen8:N76
# Gen8:N77
# Gen8:N78
# Gen8:N79
# Gen8:N80
# Gen8:N81
# Gen8:N82
# Gen8:N83
# Gen8:N84
# Gen8:N85
# Gen8:N86
# Gen8:N87
# Gen8:N88
# Gen8:N89
# Gen8:N90
# Gen8:N91
# Gen8:N92
# Gen8:N93
# Gen8:N94
# Gen8:N95
# Gen8:N96
# Gen8:N97
# Gen8:N98
# Gen8:N99
# Gen8:N100
# Gen8:N101
# Gen8:N102
# Gen8:N103
# Gen8:N104
# Gen8:N105
# Gen8:N106
# Gen8:N107
# Gen8:N108
# Gen8:N109
# Gen8:N110
# Gen8:N111
# Gen8:N112
# Gen8:N113
# Gen8:N114
# Gen8:N115
# Gen8:N116
# Gen8:N117
# Gen8:N118
# Gen8:N119
# Gen8:N120
# Gen8:N121
# Gen8:N122
# Gen8:N123
# Gen8:N124
# Gen8:N125
# Gen8:N126
# Gen8:N127
# Gen8:N128
# Gen8:N129
# Gen8:N130
# Gen8:N131
# Gen8:N132
# Gen8:N133
# Gen8:N134
# Gen8:N135
# Gen8:N136
# Gen8:N137
# Gen8:N138
# Gen8:N139
# Gen8:N140
# Gen8:N141
# Gen8:N142
# Gen8:N143
# Gen8:N144
# Gen8:N145
# Gen8:N146
# Gen8:N147
# Gen8:N148
# Gen8:N149
# Gen8:N150
# Gen8:N151
# Gen8:N152
# Gen8:N153
# Gen8:N154
# Gen8:N155
# Gen8:N156
# Gen8:N157
# Gen8:N158
# Gen8:N159
# Gen8:N160
# Gen8:N161
# Gen8:N162
# Gen8:N163
# Gen8:N164
# Gen8:N165
# Gen8:N166
# Gen8:N167
# Gen8:N168
# Gen8:N169
# Gen8:N170
# Gen8:N171
# Gen8:N172
# Gen8:N173
# Gen8:N174
# Gen8:N175
# Gen8:N176
# Gen8:N177
# Gen8:N178
# Gen8:N179
# Gen8:N180
# Gen8:N181
# Gen8:N182
# Gen8:N183
# Gen8:N184
# Gen8:N185
# Gen8:N186
# Gen8:N187
# Gen8:N188
# Gen8:N189
# Gen8:N190
# Gen8:N191
# Gen8:N192
# Gen8:N193
# Gen8:N194
# Gen8:N195
# Gen8:N196
# Gen8:N197
# Gen8:N198
# Gen8:N199
# Gen8:N200
# Gen8:N201
# Gen8:N202
# Gen8:N203
# Gen8:N204
# Gen8:N205
# Gen8:N206
# Gen8:N207
# Gen8:N208
# Gen8:N209
# Gen8:N210
# Gen8:N211
# Gen8:N212
# Gen8:N213
# Gen8:N214
# Gen8:N215
# Gen8:N216
# Gen8:N217
# Gen8:N218
# Gen8:N219
# Gen8:N220
# Gen8:N221
# Gen8:N222
# Gen8:N223
# Gen8:N224
# Gen8:N225
# Gen8:N226
# Gen8:N227
# Gen8:N228
# Gen8:N229
# Gen8:N230
# Gen8:N231
# Gen8:N232
# Gen8:N233
# Gen8:N234
# Gen8:N235
# Gen8:N236
# Gen8:N237
# Gen8:N238
# Gen8:N239
# Gen8:N240
# Gen8:N241
# Gen8:N242
# Gen8:N243
# Gen8:N244
# Gen8:N245
# Gen8:N246
# Gen8:N247
# Gen8:N248
# Gen8:N249
# Gen8:N250
# Gen8:N251
# Gen8:N252
# Gen8:N253
# Gen8:N254
# Gen8:N255
# Gen8:N256
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N1:  Gen9:N2
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N2:  Gen9:N1
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N3:  Gen9:N4
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N4:  Gen9:N3
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N5:  Gen9:N8
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N6:  Gen9:N5
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N7:  Gen9:N8
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N8:  Gen9:N5
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N9:  Gen9:N10
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N10:  Gen9:N16
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N11:  Gen9:N14
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N12:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N13:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N14:  Gen9:N11
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N15:  Gen9:N9
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N16:  Gen9:N10
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N17:  Gen9:N18
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N18:  Gen9:N17
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N19:  Gen9:N20
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N20:  Gen9:N19
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N21:  Gen9:N24
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N22:  Gen9:N10
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N23:  Gen9:N24
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N24:  Gen9:N21
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N25:  Gen9:N26
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N26:  Gen9:N25
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N27:  Gen9:N28
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N28:  Gen9:N21
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N29:  Gen9:N30
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N30:  Gen9:N29
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N31:  Gen9:N30
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N32:  Gen9:N22
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N33:  Gen9:N34
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N34:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N35:  Gen9:N36
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N36:  Gen9:N43
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N37:  Gen9:N38
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N38:  Gen9:N37
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N39:  Gen9:N40
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N40:  Gen9:N39
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N41:  Gen9:N35
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N42:  Gen9:N41
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N43:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N44:  Gen9:N36
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N45:  Gen9:N33
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N46:  Gen9:N45
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N47:  Gen9:N48
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N48:  Gen9:N47
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N49:  Gen9:N50
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N50:  Gen9:N49
# Gen9:N51:  Gen9:N52
# Gen9:N51:  Gen9:N52
# Gen9:N51:  Gen9:N52
# Gen9:N51:  Gen9:N52
# Gen9:N52:  Gen9:N49
# Gen9:N53:  Gen9:N54
# Gen9:N54:  Gen9:N53
# Gen9:N55:  Gen9:N56
# Gen9:N56:  Gen9:N55
# Gen9:N57:  Gen9:N58
# Gen9:N58:  Gen9:N57
# Gen9:N59:  Gen9:N58
# Gen9:N60:  Gen4:N16
# Gen9:N61:  Gen9:N62
# Gen9:N62:  Gen9:N61
# Gen9:N63:  Gen9:N61
# Gen9:N64:  Gen9:N17
# Gen9:N65:  Gen9:N66
# Gen9:N66:  Gen9:N65
# Gen9:N67:  Gen9:N68
# Gen9:N68:  Gen9:N67
# Gen9:N69:  Gen9:N70
# Gen9:N70:  Gen9:N69
# Gen9:N71:  Gen9:N72
# Gen9:N72:  Gen9:N10
# Gen9:N73:  Gen9:N74
# Gen9:N74:  Gen9:N73
# Gen9:N75:  Gen9:N78
# Gen9:N76:  Gen9:N73
# Gen9:N77:  Gen9:N78
# Gen9:N78:  Gen9:N75
# Gen9:N79:  Gen9:N75
# Gen9:N80:  Gen9:N73
# Gen9:N81:  Gen9:N82
# Gen9:N82:  Gen9:N81
# Gen9:N83:  Gen9:N84
# Gen9:N84:  Gen9:N12
# Gen9:N85:  Gen9:N82
# Gen9:N86:  Gen9:N81
# Gen9:N87:  Gen9:N88
# Gen9:N88:  Gen9:N87
# Gen9:N89:  Gen9:N90
# Gen9:N90:  Gen9:N89
# Gen9:N91:  Gen9:N92
# Gen9:N92:  Gen9:N91
# Gen9:N93:  Gen9:N89
# Gen9:N94:  Gen9:N93
# Gen9:N95:  Gen3:N13
# Gen9:N96:  Gen9:N95
# Gen9:N97:  Gen9:N98
# Gen9:N98:  Gen9:N97
# Gen9:N99:  Gen9:N97
# Gen9:N100:  Gen9:N99
# Gen9:N101:  Gen9:N102
# Gen9:N102:  Gen9:N101
# Gen9:N103:  Gen9:N104
# Gen9:N104:  Gen9:N103
# Gen9:N105:  Gen9:N106
# Gen9:N106:  Gen9:N105
# Gen9:N107:  Gen9:N108
# Gen9:N108:  Gen9:N107
# Gen9:N109:  Gen9:N110
# Gen9:N110:  Gen9:N109
# Gen9:N111:  Gen9:N112
# Gen9:N112:  Gen9:N111
# Gen9:N113:  Gen9:N114
# Gen9:N114:  Gen9:N113
# Gen9:N115:  Gen9:N116
# Gen9:N116:  Gen9:N115
# Gen9:N117:  Gen9:N118
# Gen9:N118:  Gen9:N117
# Gen9:N119:  Gen9:N118
# Gen9:N120:  Gen9:N15
# Gen9:N121:  Gen9:N122
# Gen9:N122:  Gen9:N121
# Gen9:N123:  Gen9:N124
# Gen9:N124:  Gen9:N123
# Gen9:N125:  Gen9:N127
# Gen9:N126:  Gen9:N125
# Gen9:N127:  Gen9:N125
# Gen9:N128:  Gen9:N127
# Gen9:N130:  Gen9:N129
# Gen9:N132:  Gen9:N129
# Gen9:N133:  Gen9:N134
# Gen9:N134:  Gen9:N133
# Gen9:N135:  Gen9:N129
# Gen9:N136:  Gen9:N132
# Gen9:N137:  Gen9:N132
# Gen9:N138:  Gen9:N137
# Gen9:N139:  Gen9:N140
# Gen9:N140:  Gen9:N143
# Gen9:N141:  Gen9:N142
# Gen9:N142:  Gen9:N141
# Gen9:N143:  Gen9:N140
# Gen9:N144:  Gen9:N143
# Gen9:N145:  Gen9:N146
# Gen9:N146:  Gen9:N145
# Gen9:N147:  Gen9:N146
# Gen9:N148:  Gen9:N147
# Gen9:N149:  Gen9:N150
# Gen9:N150:  Gen9:N149
# Gen9:N151:  Gen9:N152
# Gen9:N152:  Gen9:N151
# Gen9:N153:  Gen9:N154
# Gen9:N154:  Gen9:N153
# Gen9:N155:  Gen9:N153
# Gen9:N156:  Gen4:N19
# Gen9:N157:  Gen9:N158
# Gen9:N158:  Gen9:N157
# Gen9:N161:  Gen9:N162
# Gen9:N162:  Gen9:N161
# Gen9:N163:  Gen9:N164
# Gen9:N164:  Gen9:N163
# Gen9:N167:  Gen9:N130
# Gen9:N168:  Gen9:N165
# Gen9:N169:  Gen9:N170
# Gen9:N170:  Gen9:N169
# Gen9:N171:  Gen9:N172
# Gen9:N172:  Gen9:N171
# Gen9:N173:  Gen9:N174
# Gen9:N174:  Gen9:N173
# Gen9:N175:  Gen9:N171
# Gen9:N176:  Gen9:N175
# Gen9:N177:  Gen9:N180
# Gen9:N178:  Gen9:N180
# Gen9:N179:  Gen9:N180
# Gen9:N180:  Gen9:N177
# Gen9:N181:  Gen9:N177
# Gen9:N182:  Gen9:N181
# Gen9:N183:  Gen9:N184
# Gen9:N184:  Gen9:N183
# Gen9:N185:  Gen9:N186
# Gen9:N186:  Gen9:N185
# Gen9:N187:  Gen9:N188
# Gen9:N188:  Gen4:N20
# Gen9:N189:  Gen9:N190
# Gen9:N190:  Gen9:N189
# Gen9:N191:  Gen9:N192
# Gen9:N192:  Gen9:N191
# Gen9:N193:  Gen9:N194
# Gen9:N194:  Gen9:N193
# Gen9:N195:  Gen9:N198
# Gen9:N196:  Gen9:N195
# Gen9:N197:  Gen9:N198
# Gen9:N198:  Gen9:N195
# Gen9:N199:  Gen9:N200
# Gen9:N200:  Gen9:N199
# Gen9:N203:  Gen9:N201
# Gen9:N204:  Gen9:N201
# Gen9:N205:  Gen9:N206
# Gen9:N206:  Gen9:N205
# Gen9:N207:  Gen9:N197
# Gen9:N208:  Gen9:N207
# Gen9:N209:  Gen9:N210
# Gen9:N210:  Gen9:N209
# Gen9:N211:  Gen9:N212
# Gen9:N212:  Gen9:N211
# Gen9:N215:  Gen9:N216
# Gen9:N216:  Gen9:N215
# Gen9:N217:  Gen9:N218
# Gen9:N218:  Gen9:N217
# Gen9:N219:  Gen9:N217
# Gen9:N220:  Gen9:N217
# Gen9:N221:  Gen9:N217
# Gen9:N222:  Gen9:N221
# Gen9:N223:  Gen9:N224
# Gen9:N224:  Gen9:N223
# Gen9:N225:  Gen9:N226
# Gen9:N226:  Gen9:N225
# Gen9:N227:  Gen9:N228
# Gen9:N228:  Gen9:N227
# Gen9:N229:  Gen9:N230
# Gen9:N230:  Gen9:N229
# Gen9:N231:  Gen9:N232
# Gen9:N232:  Gen9:N231
# Gen9:N233:  Gen9:N234
# Gen9:N234:  Gen9:N233
# Gen9:N235:  Gen9:N236
# Gen9:N236:  Gen9:N235
# Gen9:N237:  Gen9:N238
# Gen9:N238:  Gen9:N237
# Gen9:N239:  Gen9:N240
# Gen9:N240:  Gen9:N239
# Gen9:N241:  Gen9:N242
# Gen9:N242:  Gen9:N241
# Gen9:N243:  Gen9:N247
# Gen9:N244:  Gen9:N247
# Gen9:N245:  Gen9:N242
# Gen9:N246:  Gen9:N241
# Gen9:N247:  Gen9:N243
# Gen9:N248:  Gen9:N243
# Gen9:N249:  Gen9:N250
# Gen9:N250:  Gen9:N249
# Gen9:N251:  Gen9:N247
# Gen9:N252:  Gen9:N250
# Gen9:N253:  Gen9:N254
# Gen9:N254:  Gen9:N253
# Gen9:N255:  Gen9:N256
# Gen9:N256:  Gen9:N255
# Gen9:N257:  Gen9:N258
# Gen9:N258:  Gen9:N257
# Gen9:N259:  Gen9:N258
# Gen9:N260:  Gen9:N259
# Gen9:N261:  Gen9:N262
# Gen9:N262:  Gen9:N261
# Gen9:N263:  Gen9:N264
# Gen9:N264:  Gen9:N261
# Gen9:N265:  Gen9:N268
# Gen9:N266:  Gen9:N268
# Gen9:N267:  Gen9:N268
# Gen9:N268:  Gen9:N265
# Gen9:N269:  Gen9:N270
# Gen9:N270:  Gen9:N269
# Gen9:N271:  Gen9:N272
# Gen9:N272:  Gen9:N271
# Gen9:N273:  Gen9:N274
# Gen9:N274:  Gen9:N273
# Gen9:N275:  Gen9:N276
# Gen9:N276:  Gen9:N275
# Gen9:N277:  Gen9:N278
# Gen9:N278:  Gen9:N277
# Gen9:N279:  Gen9:N280
# Gen9:N280:  Gen9:N279
# Gen9:N281:  Gen9:N282
# Gen9:N282:  Gen9:N262
# Gen9:N283:  Gen4:N23
# Gen9:N284:  Gen9:N283
# Gen9:N285:  Gen9:N286
# Gen9:N286:  Gen9:N285
# Gen9:N287:  Gen9:N276
# Gen9:N288:  Gen9:N275
# Gen9:N289:  Gen9:N290
# Gen9:N290:  Gen9:N289
# Gen9:N291:  Gen9:N292
# Gen9:N292:  Gen9:N301
# Gen9:N293:  Gen9:N257
# Gen9:N294:  Gen9:N293
# Gen9:N295:  Gen9:N296
# Gen9:N296:  Gen9:N283
# Gen9:N299:  Gen9:N300
# Gen9:N300:  Gen4:N24
# Gen9:N301:  Gen9:N292
# Gen9:N302:  Gen9:N301
# Gen9:N303:  Gen9:N304
# Gen9:N304:  Gen9:N293
# Gen9:N305:  Gen9:N306
# Gen9:N306:  Gen9:N313
# Gen9:N307:  Gen9:N308
# Gen9:N308:  Gen9:N307
# Gen9:N309:  Gen9:N310
# Gen9:N310:  Gen9:N309
# Gen9:N311:  Gen9:N312
# Gen9:N312:  Gen9:N311
# Gen9:N313:  Gen9:N306
# Gen9:N314:  Gen9:N313
# Gen9:N317:  Gen9:N318
# Gen9:N318:  Gen9:N317
# Gen9:N319:  Gen9:N320
# Gen9:N320:  Gen9:N319
# Gen9:N321:  Gen9:N322
# Gen9:N322:  Gen9:N321
# Gen9:N323:  Gen9:N324
# Gen9:N324:  Gen9:N323
# Gen9:N325:  Gen9:N321
# Gen9:N326:  Gen9:N325
# Gen9:N327:  Gen9:N326
# Gen9:N328:  Gen9:N326
# Gen9:N329:  Gen9:N330
# Gen9:N330:  Gen9:N329
# Gen9:N331:  Gen9:N330
# Gen9:N332:  Gen9:N330
# Gen9:N333:  Gen9:N335
# Gen9:N334:  Gen9:N333
# Gen9:N335:  Gen9:N333
# Gen9:N336:  Gen9:N333
# Gen9:N337:  Gen3:N11
# Gen9:N338:  Gen3:N11
# Gen9:N339:  Gen9:N340
# Gen9:N340:  Gen9:N339
# Gen9:N341:  Gen9:N342
# Gen9:N342:  Gen9:N341
# Gen9:N343:  Gen9:N344
# Gen9:N344:  Gen9:N343
# Gen9:N345:  Gen9:N346
# Gen9:N346:  Gen9:N345
# Gen9:N347:  Gen9:N348
# Gen9:N348:  Gen9:N347
# Gen9:N349:  Gen9:N350
# Gen9:N350:  Gen9:N349
# Gen9:N351:  Gen9:N349
# Gen9:N352:  Gen9:N350
# Gen9:N353:  Gen9:N354
# Gen9:N354:  Gen9:N353
# Gen9:N355:  Gen9:N356
# Gen9:N356:  Gen9:N354
# Gen9:N357:  Gen9:N358
# Gen9:N358:  Gen9:N357
# Gen9:N359:  Gen9:N357
# Gen9:N360:  Gen9:N359
# Gen9:N361:  Gen9:N362
# Gen9:N362:  Gen9:N361
# Gen9:N363:  Gen9:N364
# Gen9:N364:  Gen9:N363
# Gen9:N365:  Gen9:N366
# Gen9:N366:  Gen9:N365
# Gen9:N367:  Gen4:N26
# Gen9:N368:  Gen9:N367
# Gen9:N369:  Gen9:N370
# Gen9:N370:  Gen9:N369
# Gen9:N371:  Gen9:N372
# Gen9:N372:  Gen9:N358
# Gen9:N373:  Gen9:N374
# Gen9:N374:  Gen9:N373
# Gen9:N377:  Gen9:N380
# Gen9:N378:  Gen9:N380
# Gen9:N379:  Gen9:N380
# Gen9:N380:  Gen9:N377
# Gen9:N381:  Gen9:N382
# Gen9:N382:  Gen9:N381
# Gen9:N385:  Gen9:N386
# Gen9:N386:  Gen9:N393
# Gen9:N387:  Gen9:N388
# Gen9:N388:  Gen9:N387
# Gen9:N389:  Gen9:N391
# Gen9:N390:  Gen9:N389
# Gen9:N391:  Gen9:N389
# Gen9:N392:  Gen9:N391
# Gen9:N393:  Gen9:N386
# Gen9:N394:  Gen9:N399
# Gen9:N395:  Gen9:N396
# Gen9:N396:  Gen9:N395
# Gen9:N397:  Gen9:N398
# Gen9:N398:  Gen9:N397
# Gen9:N399:  Gen9:N394
# Gen9:N400:  Gen9:N399
# Gen9:N402:  Gen9:N405
# Gen9:N404:  Gen9:N401
# Gen9:N406:  Gen9:N405
# Gen9:N408:  Gen9:N405
# Gen9:N409:  Gen9:N410
# Gen9:N410:  Gen9:N409
# Gen9:N411:  Gen9:N412
# Gen9:N412:  Gen9:N411
# Gen9:N413:  Gen9:N414
# Gen9:N414:  Gen9:N413
# Gen9:N415:  Gen9:N404
# Gen9:N416:  Gen9:N415
# Gen9:N417:  Gen9:N418
# Gen9:N418:  Gen9:N417
# Gen9:N419:  Gen9:N420
# Gen9:N420:  Gen9:N419
# Gen9:N421:  Gen9:N422
# Gen9:N422:  Gen9:N421
# Gen9:N423:  Gen9:N424
# Gen9:N424:  Gen9:N423
# Gen9:N425:  Gen9:N426
# Gen9:N426:  Gen9:N425
# Gen9:N427:  Gen9:N431
# Gen9:N428:  Gen9:N427
# Gen9:N429:  Gen9:N427
# Gen9:N430:  Gen9:N427
# Gen9:N431:  Gen9:N427
# Gen9:N432:  Gen9:N427
# Gen9:N433:  Gen9:N434
# Gen9:N434:  Gen9:N433
# Gen9:N435:  Gen9:N436
# Gen9:N436:  Gen9:N435
# Gen9:N437:  Gen9:N438
# Gen9:N438:  Gen9:N437
# Gen9:N439:  Gen9:N440
# Gen9:N440:  Gen9:N418
# Gen9:N441:  Gen9:N443
# Gen9:N442:  Gen9:N441
# Gen9:N443:  Gen9:N441
# Gen9:N444:  Gen9:N441
# Gen9:N446:  Gen9:N445
# Gen9:N448:  Gen9:N445
# Gen9:N449:  Gen9:N450
# Gen9:N450:  Gen9:N451
# Gen9:N451:  Gen9:N450
# Gen9:N452:  Gen9:N450
# Gen9:N453:  Gen9:N449
# Gen9:N454:  Gen9:N453
# Gen9:N455:  Gen9:N449
# Gen9:N456:  Gen9:N451
# Gen9:N457:  Gen9:N460
# Gen9:N458:  Gen9:N460
# Gen9:N459:  Gen9:N460
# Gen9:N460:  Gen9:N457
# Gen9:N461:  Gen9:N462
# Gen9:N462:  Gen9:N461
# Gen9:N463:  Gen9:N461
# Gen9:N464:  Gen9:N461
# Gen9:N465:  Gen9:N466
# Gen9:N466:  Gen9:N465
# Gen9:N467:  Gen9:N468
# Gen9:N468:  Gen9:N467
# Gen9:N469:  Gen9:N470
# Gen9:N470:  Gen9:N469
# Gen9:N471:  Gen9:N472
# Gen9:N472:  Gen9:N471
# Gen9:N473:  Gen9:N474
# Gen9:N474:  Gen9:N473
# Gen9:N475:  Gen9:N473
# Gen9:N476:  Gen9:N473
# Gen9:N477:  Gen9:N472
# Gen9:N478:  Gen9:N477
# Gen9:N479:  Gen9:N477
# Gen9:N480:  Gen9:N477
# Gen9:N484:  Gen9:N481
# Gen9:N485:  Gen9:N486
# Gen9:N486:  Gen9:N485
# Gen9:N487:  Gen9:N484
# Gen9:N488:  Gen9:N486
# Gen9:N489:  Gen9:N490
# Gen9:N490:  Gen9:N489
# Gen9:N491:  Gen9:N492
# Gen9:N492:  Gen9:N491
# Gen9:N495:  Gen9:N496
# Gen9:N496:  Gen9:N495
# Gen9:N497:  Gen9:N498
# Gen9:N498:  Gen9:N497
# Gen9:N499:  Gen9:N500
# Gen9:N500:  Gen9:N499
# Gen9:N501:  Gen9:N502
# Gen9:N502:  Gen9:N501
# Gen9:N503:  Gen9:N504
# Gen9:N504:  Gen9:N501
# Gen9:N507:  Gen9:N482
# Gen9:N508:  Gen9:N509
# Gen9:N509:  Gen9:N508
# Gen9:N510:  Gen9:N508
# Gen9:N511:  Gen9:N512
# Gen9:N512:  Gen9:N511
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/3622047550.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.8508333333333334
# (0.0, 100.0)

# %% [markdown]
# # G +5

# %%
new_dataset = {}
# define childs
# select seq from last generation to mutate
simulated_dataset = predicted_dataset

last_gen = 9
last_gen_dataset = {}
for id in simulated_dataset:
    G = int(id.split(':')[0].replace('Gen',''))
    if G == last_gen:
        last_gen_dataset[id] = simulated_dataset[id]

# for end-node make childs
c = 0

G = last_gen
parents = last_gen_dataset
G += 1
for id in last_gen_dataset:
    print(id)
    seq = parents[id] 
    #right 
    c+=1
    N = round( r.mean() ) # N = number of mut per generation
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq
    #left 
    seq = parents[id] 
    c+=1
    pos = get_truncated_normal(mu, std, low=1, upp=L).rvs(N)
    refs = []
    for p in pos :
        refs.append(seq[int(p)])
    X_test = pd.DataFrame( { 'ref' : refs, 'pos' : pos } )
    X_test['ref'] = X_test['ref'].map(di)
    y_pred = randomforest.predict(X_test)
    y_Pred = reverse_map(list(y_pred))
    for i in range(len(pos)):
        p = int(pos[i])
        seq = seq[:p] + y_Pred[i] + seq[p+1:] # insert new mutated base in sequence
    new_dataset['Gen'+str(G)+":N"+str(c)]=seq

predicted_dataset = train_dataset | new_dataset

# 1. pairwise align
path = './data/tmp/'

simulated_dataset = predicted_dataset
ids = list(simulated_dataset)
scores = []
score_matrix = pd.DataFrame(np.zeros((len(ids),len(ids))))
score_matrix.index = ids
score_matrix.columns = ids
while len(ids) > 1:
    id_ref = ids.pop(0)
    ref = simulated_dataset[id_ref]
    for id_tar in ids:
        tar = simulated_dataset[id_tar]
        # print(len(ref), len(tar))
        score = dataset_simulator.needle_align_code(ref, tar)
        # print(id_ref , id_tar , score, len(ref), len(tar))
        scores.append([id_ref, id_tar, score ])  #add to the end

scores_df = pd.DataFrame(scores)  
# print(scores_df)


for s in scores:
    score_matrix.loc[s[0] , s[1]] = 100 - float(s[2])
    score_matrix.loc[s[1] , s[0]] =  100 - float(s[2])
score_matrix

names = set( score_matrix.index )

meta = []
for id in names:
    N = str(id).split('N')[1]
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([Gen,N, seq])
meta = pd.DataFrame(meta, columns=['Gen','N', 'seq'])

import pandas as pd
import numpy as np

edges = []

X = score_matrix
# X = X.T
k = 2
for i in X.index:
    Y = X.nsmallest(k, i)
    Y = Y.T
    Y = Y[Y.index.str.startswith(i)]
    Y = Y.loc[:, Y.any()]

    for j in Y.index:
        targets = list(Y.columns)
        for c in targets:
            if c != i:
               print(i + ": ", c)
               edges.append([i, c])

Edges = pd.DataFrame(edges)
id_map = {}
i = 1
names = set( Edges[1] ) | set( Edges[0] ) 
for id in names:
    id_map[id] = str(id)
    i+=1
id_map
edgelist = Edges
edgelist.columns = ['source','target']

fig = plt.figure(1, figsize=(20, 20), dpi=60)
G = nx.Graph()
G = nx.from_pandas_edgelist(edgelist)

fig = plt.figure(1, figsize=(20, 20), dpi=50)
nx.draw_kamada_kawai(G, with_labels=True, node_size=500)


meta = []
for id in names:
    N = str(id).split('N')[1]
    ID = id
    Gen = str(id).split(':')[0].replace('Gen','')
    seq = simulated_dataset[id]
    meta.append([ Gen, ID, seq])
meta = pd.DataFrame(meta, columns=['Gen','id', 'seq'])

meta
# combine edgelist and meta to add date
meta.columns = ['source_gen','source','seq_ref']
conneted_sequences = pd.merge(meta, edgelist)
meta.columns = ['target_gen','target','seq_tar']
conneted_sequences = pd.merge(meta, conneted_sequences)
conneted_sequences['gen_dif'] = abs(conneted_sequences['source_gen'].astype(int) - conneted_sequences['target_gen'].astype(int))
conneted_sequences = conneted_sequences.loc[conneted_sequences.gen_dif != 0,:]
# conneted_sequences
conneted_sequences = conneted_sequences.reset_index()
conneted_sequences



vars_all  = pd.DataFrame()
mut_rate  = []
for pair in conneted_sequences.iterrows() :
    sr = pair[1][3]
    st = pair[1][6]
    alignments = pairwise2.align.globalms(sr, st, 5, -4, -3, -.1)
    alignment = format_alignment(*alignments[0]).split('\n')
    ref_bases = [char for char in alignment[0]] 
    tar_bases = [char for char in alignment[2]] 
    pos = [ i for i in range(len(alignment[2])) ]
    vars = [ref_bases, tar_bases, pos]
    vars = pd.DataFrame(vars).T
    vars.columns = ['ref','tar','pos']
    vars = vars.loc[vars.ref != vars.tar ,:]
    vars.to_csv( "./data/align/" + str( str(pair[1][1]) + str(pair[1][4]) ) )
    vars_all = vars_all.append(vars) 
    mut_rate.append([vars.shape[0] , pair[1][7]])

vars_all.to_csv( './data/'+version+'/vars'+'.csv')
mut_rate = pd.DataFrame(mut_rate, columns=['x','y'])
mut_rate.to_csv( './data/'+version+'/mut_rate.csv')
from sklearn import linear_model

mut_rate_all = mut_rate

mut_rate_all = mut_rate_all[mut_rate_all.x > 0]
mut_rate_all = mut_rate_all[mut_rate_all.y > 0]
mut_rate_all['r'] = mut_rate_all.x  / mut_rate_all.y

print(mut_rate_all['r'].mean())

vars_G7 = vars_all


vars_all
fig, ax = plt.subplots(figsize = (10,5))
# plt.style.use("ggplot")
# vars.pos.plot.hist(bins=100, linewidth=1, ax = ax, density = True, normed=True)
vars_all.pos.plot(kind ='hist', bins=250, width=0.5, ax = ax, density = True)
vars_all.pos.plot.kde(c = 'r', ax = ax, secondary_y=True)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# Gen9:N1
# Gen9:N2
# Gen9:N3
# Gen9:N4
# Gen9:N5
# Gen9:N6
# Gen9:N7
# Gen9:N8
# Gen9:N9
# Gen9:N10
# Gen9:N11
# Gen9:N12
# Gen9:N13
# Gen9:N14
# Gen9:N15
# Gen9:N16
# Gen9:N17
# Gen9:N18
# Gen9:N19
# Gen9:N20
# Gen9:N21
# Gen9:N22
# Gen9:N23
# Gen9:N24
# Gen9:N25
# Gen9:N26
# Gen9:N27
# Gen9:N28
# Gen9:N29
# Gen9:N30
# Gen9:N31
# Gen9:N32
# Gen9:N33
# Gen9:N34
# Gen9:N35
# Gen9:N36
# Gen9:N37
# Gen9:N38
# Gen9:N39
# Gen9:N40
# Gen9:N41
# Gen9:N42
# Gen9:N43
# Gen9:N44
# Gen9:N45
# Gen9:N46
# Gen9:N47
# Gen9:N48
# Gen9:N49
# Gen9:N50
# Gen9:N51
# Gen9:N52
# Gen9:N53
# Gen9:N54
# Gen9:N55
# Gen9:N56
# Gen9:N57
# Gen9:N58
# Gen9:N59
# Gen9:N60
# Gen9:N61
# Gen9:N62
# Gen9:N63
# Gen9:N64
# Gen9:N65
# Gen9:N66
# Gen9:N67
# Gen9:N68
# Gen9:N69
# Gen9:N70
# Gen9:N71
# Gen9:N72
# Gen9:N73
# Gen9:N74
# Gen9:N75
# Gen9:N76
# Gen9:N77
# Gen9:N78
# Gen9:N79
# Gen9:N80
# Gen9:N81
# Gen9:N82
# Gen9:N83
# Gen9:N84
# Gen9:N85
# Gen9:N86
# Gen9:N87
# Gen9:N88
# Gen9:N89
# Gen9:N90
# Gen9:N91
# Gen9:N92
# Gen9:N93
# Gen9:N94
# Gen9:N95
# Gen9:N96
# Gen9:N97
# Gen9:N98
# Gen9:N99
# Gen9:N100
# Gen9:N101
# Gen9:N102
# Gen9:N103
# Gen9:N104
# Gen9:N105
# Gen9:N106
# Gen9:N107
# Gen9:N108
# Gen9:N109
# Gen9:N110
# Gen9:N111
# Gen9:N112
# Gen9:N113
# Gen9:N114
# Gen9:N115
# Gen9:N116
# Gen9:N117
# Gen9:N118
# Gen9:N119
# Gen9:N120
# Gen9:N121
# Gen9:N122
# Gen9:N123
# Gen9:N124
# Gen9:N125
# Gen9:N126
# Gen9:N127
# Gen9:N128
# Gen9:N129
# Gen9:N130
# Gen9:N131
# Gen9:N132
# Gen9:N133
# Gen9:N134
# Gen9:N135
# Gen9:N136
# Gen9:N137
# Gen9:N138
# Gen9:N139
# Gen9:N140
# Gen9:N141
# Gen9:N142
# Gen9:N143
# Gen9:N144
# Gen9:N145
# Gen9:N146
# Gen9:N147
# Gen9:N148
# Gen9:N149
# Gen9:N150
# Gen9:N151
# Gen9:N152
# Gen9:N153
# Gen9:N154
# Gen9:N155
# Gen9:N156
# Gen9:N157
# Gen9:N158
# Gen9:N159
# Gen9:N160
# Gen9:N161
# Gen9:N162
# Gen9:N163
# Gen9:N164
# Gen9:N165
# Gen9:N166
# Gen9:N167
# Gen9:N168
# Gen9:N169
# Gen9:N170
# Gen9:N171
# Gen9:N172
# Gen9:N173
# Gen9:N174
# Gen9:N175
# Gen9:N176
# Gen9:N177
# Gen9:N178
# Gen9:N179
# Gen9:N180
# Gen9:N181
# Gen9:N182
# Gen9:N183
# Gen9:N184
# Gen9:N185
# Gen9:N186
# Gen9:N187
# Gen9:N188
# Gen9:N189
# Gen9:N190
# Gen9:N191
# Gen9:N192
# Gen9:N193
# Gen9:N194
# Gen9:N195
# Gen9:N196
# Gen9:N197
# Gen9:N198
# Gen9:N199
# Gen9:N200
# Gen9:N201
# Gen9:N202
# Gen9:N203
# Gen9:N204
# Gen9:N205
# Gen9:N206
# Gen9:N207
# Gen9:N208
# Gen9:N209
# Gen9:N210
# Gen9:N211
# Gen9:N212
# Gen9:N213
# Gen9:N214
# Gen9:N215
# Gen9:N216
# Gen9:N217
# Gen9:N218
# Gen9:N219
# Gen9:N220
# Gen9:N221
# Gen9:N222
# Gen9:N223
# Gen9:N224
# Gen9:N225
# Gen9:N226
# Gen9:N227
# Gen9:N228
# Gen9:N229
# Gen9:N230
# Gen9:N231
# Gen9:N232
# Gen9:N233
# Gen9:N234
# Gen9:N235
# Gen9:N236
# Gen9:N237
# Gen9:N238
# Gen9:N239
# Gen9:N240
# Gen9:N241
# Gen9:N242
# Gen9:N243
# Gen9:N244
# Gen9:N245
# Gen9:N246
# Gen9:N247
# Gen9:N248
# Gen9:N249
# Gen9:N250
# Gen9:N251
# Gen9:N252
# Gen9:N253
# Gen9:N254
# Gen9:N255
# Gen9:N256
# Gen9:N257
# Gen9:N258
# Gen9:N259
# Gen9:N260
# Gen9:N261
# Gen9:N262
# Gen9:N263
# Gen9:N264
# Gen9:N265
# Gen9:N266
# Gen9:N267
# Gen9:N268
# Gen9:N269
# Gen9:N270
# Gen9:N271
# Gen9:N272
# Gen9:N273
# Gen9:N274
# Gen9:N275
# Gen9:N276
# Gen9:N277
# Gen9:N278
# Gen9:N279
# Gen9:N280
# Gen9:N281
# Gen9:N282
# Gen9:N283
# Gen9:N284
# Gen9:N285
# Gen9:N286
# Gen9:N287
# Gen9:N288
# Gen9:N289
# Gen9:N290
# Gen9:N291
# Gen9:N292
# Gen9:N293
# Gen9:N294
# Gen9:N295
# Gen9:N296
# Gen9:N297
# Gen9:N298
# Gen9:N299
# Gen9:N300
# Gen9:N301
# Gen9:N302
# Gen9:N303
# Gen9:N304
# Gen9:N305
# Gen9:N306
# Gen9:N307
# Gen9:N308
# Gen9:N309
# Gen9:N310
# Gen9:N311
# Gen9:N312
# Gen9:N313
# Gen9:N314
# Gen9:N315
# Gen9:N316
# Gen9:N317
# Gen9:N318
# Gen9:N319
# Gen9:N320
# Gen9:N321
# Gen9:N322
# Gen9:N323
# Gen9:N324
# Gen9:N325
# Gen9:N326
# Gen9:N327
# Gen9:N328
# Gen9:N329
# Gen9:N330
# Gen9:N331
# Gen9:N332
# Gen9:N333
# Gen9:N334
# Gen9:N335
# Gen9:N336
# Gen9:N337
# Gen9:N338
# Gen9:N339
# Gen9:N340
# Gen9:N341
# Gen9:N342
# Gen9:N343
# Gen9:N344
# Gen9:N345
# Gen9:N346
# Gen9:N347
# Gen9:N348
# Gen9:N349
# Gen9:N350
# Gen9:N351
# Gen9:N352
# Gen9:N353
# Gen9:N354
# Gen9:N355
# Gen9:N356
# Gen9:N357
# Gen9:N358
# Gen9:N359
# Gen9:N360
# Gen9:N361
# Gen9:N362
# Gen9:N363
# Gen9:N364
# Gen9:N365
# Gen9:N366
# Gen9:N367
# Gen9:N368
# Gen9:N369
# Gen9:N370
# Gen9:N371
# Gen9:N372
# Gen9:N373
# Gen9:N374
# Gen9:N375
# Gen9:N376
# Gen9:N377
# Gen9:N378
# Gen9:N379
# Gen9:N380
# Gen9:N381
# Gen9:N382
# Gen9:N383
# Gen9:N384
# Gen9:N385
# Gen9:N386
# Gen9:N387
# Gen9:N388
# Gen9:N389
# Gen9:N390
# Gen9:N391
# Gen9:N392
# Gen9:N393
# Gen9:N394
# Gen9:N395
# Gen9:N396
# Gen9:N397
# Gen9:N398
# Gen9:N399
# Gen9:N400
# Gen9:N401
# Gen9:N402
# Gen9:N403
# Gen9:N404
# Gen9:N405
# Gen9:N406
# Gen9:N407
# Gen9:N408
# Gen9:N409
# Gen9:N410
# Gen9:N411
# Gen9:N412
# Gen9:N413
# Gen9:N414
# Gen9:N415
# Gen9:N416
# Gen9:N417
# Gen9:N418
# Gen9:N419
# Gen9:N420
# Gen9:N421
# Gen9:N422
# Gen9:N423
# Gen9:N424
# Gen9:N425
# Gen9:N426
# Gen9:N427
# Gen9:N428
# Gen9:N429
# Gen9:N430
# Gen9:N431
# Gen9:N432
# Gen9:N433
# Gen9:N434
# Gen9:N435
# Gen9:N436
# Gen9:N437
# Gen9:N438
# Gen9:N439
# Gen9:N440
# Gen9:N441
# Gen9:N442
# Gen9:N443
# Gen9:N444
# Gen9:N445
# Gen9:N446
# Gen9:N447
# Gen9:N448
# Gen9:N449
# Gen9:N450
# Gen9:N451
# Gen9:N452
# Gen9:N453
# Gen9:N454
# Gen9:N455
# Gen9:N456
# Gen9:N457
# Gen9:N458
# Gen9:N459
# Gen9:N460
# Gen9:N461
# Gen9:N462
# Gen9:N463
# Gen9:N464
# Gen9:N465
# Gen9:N466
# Gen9:N467
# Gen9:N468
# Gen9:N469
# Gen9:N470
# Gen9:N471
# Gen9:N472
# Gen9:N473
# Gen9:N474
# Gen9:N475
# Gen9:N476
# Gen9:N477
# Gen9:N478
# Gen9:N479
# Gen9:N480
# Gen9:N481
# Gen9:N482
# Gen9:N483
# Gen9:N484
# Gen9:N485
# Gen9:N486
# Gen9:N487
# Gen9:N488
# Gen9:N489
# Gen9:N490
# Gen9:N491
# Gen9:N492
# Gen9:N493
# Gen9:N494
# Gen9:N495
# Gen9:N496
# Gen9:N497
# Gen9:N498
# Gen9:N499
# Gen9:N500
# Gen9:N501
# Gen9:N502
# Gen9:N503
# Gen9:N504
# Gen9:N505
# Gen9:N506
# Gen9:N507
# Gen9:N508
# Gen9:N509
# Gen9:N510
# Gen9:N511
# Gen9:N512
# Gen0:N0:  Gen1:N1
# Gen1:N1:  Gen0:N0
# Gen1:N2:  Gen0:N0
# Gen2:N3:  Gen1:N1
# Gen2:N4:  Gen1:N1
# Gen2:N5:  Gen1:N2
# Gen2:N6:  Gen1:N2
# Gen3:N7:  Gen2:N3
# Gen3:N8:  Gen2:N3
# Gen3:N9:  Gen2:N4
# Gen3:N10:  Gen2:N4
# Gen3:N11:  Gen2:N5
# Gen3:N12:  Gen2:N5
# Gen3:N13:  Gen2:N6
# Gen3:N14:  Gen2:N6
# Gen4:N15:  Gen3:N7
# Gen4:N16:  Gen3:N7
# Gen4:N17:  Gen1:N1
# Gen4:N18:  Gen3:N8
# Gen4:N19:  Gen3:N9
# Gen4:N20:  Gen3:N9
# Gen4:N21:  Gen3:N10
# Gen4:N22:  Gen3:N10
# Gen4:N23:  Gen3:N11
# Gen4:N24:  Gen3:N11
# Gen4:N25:  Gen2:N5
# Gen4:N26:  Gen3:N12
# Gen4:N27:  Gen3:N13
# Gen4:N28:  Gen3:N13
# Gen4:N29:  Gen3:N14
# Gen4:N30:  Gen3:N14
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N1:  Gen10:N2
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N2:  Gen10:N1
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N3:  Gen10:N4
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N4:  Gen10:N3
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N5:  Gen10:N6
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N6:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N7:  Gen10:N5
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N8:  Gen10:N7
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N9:  Gen10:N10
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N10:  Gen10:N13
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N11:  Gen10:N12
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N12:  Gen10:N11
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N13:  Gen10:N10
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N14:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N15:  Gen10:N13
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N16:  Gen10:N15
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N17:  Gen10:N18
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N18:  Gen10:N17
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N19:  Gen10:N20
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N20:  Gen10:N19
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N21:  Gen10:N23
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N22:  Gen10:N28
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N23:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N24:  Gen10:N21
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N25:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N26:  Gen10:N23
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N27:  Gen10:N21
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N28:  Gen10:N22
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N29:  Gen10:N30
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N30:  Gen10:N29
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N31:  Gen10:N32
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N32:  Gen10:N25
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N33:  Gen10:N34
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N34:  Gen10:N33
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N35:  Gen10:N36
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N36:  Gen10:N33
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N37:  Gen10:N38
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N38:  Gen10:N40
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N39:  Gen10:N37
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N40:  Gen10:N38
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N41:  Gen10:N42
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N42:  Gen10:N41
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N43:  Gen10:N44
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N44:  Gen10:N43
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N45:  Gen10:N46
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N46:  Gen10:N45
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N47:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N48:  Gen10:N46
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N49:  Gen10:N50
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N50:  Gen10:N51
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N51:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N52:  Gen10:N50
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N53:  Gen10:N54
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N54:  Gen10:N53
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N55:  Gen10:N56
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N56:  Gen10:N55
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N57:  Gen10:N8
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N58:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N59:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N60:  Gen10:N57
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N61:  Gen10:N62
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N62:  Gen10:N50
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N63:  Gen10:N43
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N64:  Gen10:N63
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N65:  Gen10:N66
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N66:  Gen10:N65
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N67:  Gen10:N68
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N68:  Gen10:N67
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N69:  Gen10:N71
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N70:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N71:  Gen10:N69
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N72:  Gen10:N86
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N73:  Gen10:N74
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N74:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N75:  Gen10:N73
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N76:  Gen10:N75
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N77:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N78:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N79:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N80:  Gen10:N72
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N81:  Gen10:N82
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N82:  Gen10:N81
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N83:  Gen10:N84
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N84:  Gen10:N83
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N85:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N86:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N87:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N88:  Gen10:N72
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N89:  Gen10:N65
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N90:  Gen10:N66
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N91:  Gen10:N92
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N92:  Gen10:N91
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N93:  Gen10:N94
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N94:  Gen10:N93
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N95:  Gen10:N96
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N96:  Gen10:N93
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# Gen10:N97:  Gen10:N98
# ...
# Gen10:N636:  Gen10:N635
# Gen10:N637:  Gen10:N638
# Gen10:N638:  Gen10:N637
# Gen10:N639:  Gen10:N640
# Gen10:N640:  Gen10:N639
# Gen10:N641:  Gen10:N642
# Gen10:N642:  Gen10:N641
# Gen10:N643:  Gen10:N644
# Gen10:N644:  Gen10:N643
# Gen10:N645:  Gen10:N646
# Gen10:N646:  Gen10:N645
# Gen10:N647:  Gen10:N645
# Gen10:N648:  Gen10:N645
# Gen10:N649:  Gen10:N650
# Gen10:N650:  Gen10:N649
# Gen10:N651:  Gen10:N652
# Gen10:N652:  Gen10:N651
# Gen10:N653:  Gen10:N654
# Gen10:N654:  Gen10:N653
# Gen10:N655:  Gen10:N644
# Gen10:N656:  Gen10:N655
# Gen10:N657:  Gen10:N658
# Gen10:N658:  Gen10:N657
# Gen10:N659:  Gen10:N660
# Gen10:N660:  Gen10:N659
# Gen10:N661:  Gen10:N662
# Gen10:N662:  Gen10:N663
# Gen10:N663:  Gen10:N662
# Gen10:N664:  Gen10:N663
# Gen10:N665:  Gen10:N666
# Gen10:N666:  Gen10:N665
# Gen10:N667:  Gen10:N668
# Gen10:N668:  Gen10:N667
# Gen10:N669:  Gen10:N666
# Gen10:N670:  Gen10:N666
# Gen10:N671:  Gen10:N672
# Gen10:N672:  Gen10:N671
# Gen10:N673:  Gen10:N674
# Gen10:N674:  Gen10:N673
# Gen10:N675:  Gen10:N674
# Gen10:N676:  Gen4:N23
# Gen10:N677:  Gen3:N11
# Gen10:N678:  Gen10:N677
# Gen10:N679:  Gen10:N680
# Gen10:N680:  Gen10:N679
# Gen10:N681:  Gen10:N682
# Gen10:N682:  Gen10:N681
# Gen10:N683:  Gen10:N684
# Gen10:N684:  Gen10:N683
# Gen10:N685:  Gen10:N687
# Gen10:N686:  Gen10:N685
# Gen10:N687:  Gen10:N685
# Gen10:N688:  Gen10:N680
# Gen10:N689:  Gen10:N690
# Gen10:N690:  Gen10:N689
# Gen10:N691:  Gen10:N692
# Gen10:N692:  Gen10:N691
# Gen10:N693:  Gen10:N694
# Gen10:N694:  Gen10:N693
# Gen10:N695:  Gen10:N696
# Gen10:N696:  Gen10:N695
# Gen10:N697:  Gen10:N698
# Gen10:N698:  Gen10:N697
# Gen10:N699:  Gen10:N700
# Gen10:N700:  Gen10:N699
# Gen10:N701:  Gen10:N702
# Gen10:N702:  Gen10:N701
# Gen10:N703:  Gen10:N702
# Gen10:N704:  Gen10:N702
# Gen10:N705:  Gen10:N706
# Gen10:N706:  Gen10:N705
# Gen10:N707:  Gen10:N705
# Gen10:N708:  Gen10:N707
# Gen10:N709:  Gen10:N710
# Gen10:N710:  Gen10:N709
# Gen10:N711:  Gen10:N712
# Gen10:N712:  Gen10:N711
# Gen10:N713:  Gen10:N714
# Gen10:N714:  Gen10:N713
# Gen10:N715:  Gen10:N716
# Gen10:N716:  Gen10:N715
# Gen10:N717:  Gen10:N713
# Gen10:N718:  Gen10:N717
# Gen10:N719:  Gen10:N720
# Gen10:N720:  Gen10:N719
# Gen10:N721:  Gen10:N722
# Gen10:N722:  Gen10:N721
# Gen10:N723:  Gen10:N724
# Gen10:N724:  Gen10:N723
# Gen10:N725:  Gen10:N721
# Gen10:N726:  Gen10:N725
# Gen10:N729:  Gen10:N730
# Gen10:N730:  Gen10:N729
# Gen10:N733:  Gen4:N26
# Gen10:N734:  Gen4:N26
# Gen10:N735:  Gen10:N736
# Gen10:N736:  Gen10:N735
# Gen10:N737:  Gen10:N738
# Gen10:N738:  Gen10:N737
# Gen10:N739:  Gen10:N737
# Gen10:N740:  Gen10:N737
# Gen10:N741:  Gen10:N742
# Gen10:N742:  Gen10:N741
# Gen10:N745:  Gen10:N746
# Gen10:N746:  Gen10:N745
# Gen10:N747:  Gen10:N741
# Gen10:N748:  Gen10:N747
# Gen10:N749:  Gen10:N751
# Gen10:N750:  Gen10:N751
# Gen10:N755:  Gen10:N759
# Gen10:N756:  Gen10:N755
# Gen10:N759:  Gen10:N755
# Gen10:N760:  Gen10:N753
# Gen10:N761:  Gen10:N762
# Gen10:N762:  Gen10:N761
# Gen10:N763:  Gen10:N764
# Gen10:N764:  Gen10:N763
# Gen10:N765:  Gen10:N766
# Gen10:N766:  Gen10:N765
# Gen10:N767:  Gen10:N765
# Gen10:N768:  Gen10:N765
# Gen10:N769:  Gen10:N770
# Gen10:N770:  Gen10:N769
# Gen10:N771:  Gen10:N772
# Gen10:N772:  Gen10:N771
# Gen10:N773:  Gen10:N774
# Gen10:N774:  Gen10:N773
# Gen10:N775:  Gen10:N776
# Gen10:N776:  Gen10:N775
# Gen10:N777:  Gen10:N778
# Gen10:N778:  Gen10:N782
# Gen10:N779:  Gen10:N780
# Gen10:N780:  Gen10:N779
# Gen10:N781:  Gen10:N782
# Gen10:N782:  Gen10:N778
# Gen10:N783:  Gen10:N784
# Gen10:N784:  Gen10:N783
# Gen10:N785:  Gen10:N774
# Gen10:N786:  Gen10:N773
# Gen10:N787:  Gen10:N788
# Gen10:N788:  Gen10:N787
# Gen10:N789:  Gen10:N790
# Gen10:N790:  Gen10:N785
# Gen10:N791:  Gen10:N792
# Gen10:N792:  Gen10:N791
# Gen10:N793:  Gen10:N794
# Gen10:N794:  Gen10:N793
# Gen10:N795:  Gen10:N796
# Gen10:N796:  Gen10:N795
# Gen10:N799:  Gen10:N800
# Gen10:N800:  Gen10:N787
# Gen10:N803:  Gen10:N804
# Gen10:N804:  Gen10:N803
# Gen10:N805:  Gen10:N801
# Gen10:N806:  Gen10:N801
# Gen10:N807:  Gen10:N808
# Gen10:N808:  Gen10:N807
# Gen10:N809:  Gen10:N803
# Gen10:N810:  Gen10:N803
# Gen10:N811:  Gen10:N803
# Gen10:N812:  Gen10:N809
# Gen10:N813:  Gen10:N803
# Gen10:N814:  Gen10:N803
# Gen10:N815:  Gen10:N803
# Gen10:N816:  Gen10:N803
# Gen10:N817:  Gen10:N818
# Gen10:N818:  Gen10:N817
# Gen10:N819:  Gen10:N820
# Gen10:N820:  Gen10:N828
# Gen10:N821:  Gen10:N822
# Gen10:N822:  Gen10:N821
# Gen10:N825:  Gen10:N826
# Gen10:N826:  Gen10:N825
# Gen10:N827:  Gen10:N828
# Gen10:N828:  Gen10:N820
# Gen10:N829:  Gen10:N808
# Gen10:N830:  Gen10:N828
# Gen10:N831:  Gen10:N829
# Gen10:N832:  Gen10:N831
# Gen10:N833:  Gen10:N834
# Gen10:N834:  Gen10:N833
# Gen10:N835:  Gen10:N836
# Gen10:N836:  Gen10:N835
# Gen10:N837:  Gen10:N838
# Gen10:N838:  Gen10:N837
# Gen10:N839:  Gen10:N840
# Gen10:N840:  Gen10:N839
# Gen10:N841:  Gen10:N842
# Gen10:N842:  Gen10:N841
# Gen10:N843:  Gen10:N842
# Gen10:N844:  Gen10:N836
# Gen10:N845:  Gen10:N846
# Gen10:N846:  Gen10:N845
# Gen10:N849:  Gen10:N850
# Gen10:N850:  Gen10:N849
# Gen10:N851:  Gen10:N852
# Gen10:N852:  Gen10:N851
# Gen10:N853:  Gen10:N863
# Gen10:N854:  Gen10:N853
# Gen10:N855:  Gen10:N853
# Gen10:N856:  Gen10:N853
# Gen10:N857:  Gen10:N855
# Gen10:N858:  Gen10:N855
# Gen10:N859:  Gen10:N856
# Gen10:N860:  Gen10:N859
# Gen10:N863:  Gen10:N853
# Gen10:N864:  Gen10:N863
# Gen10:N865:  Gen10:N866
# Gen10:N866:  Gen10:N865
# Gen10:N867:  Gen10:N868
# Gen10:N868:  Gen10:N867
# Gen10:N869:  Gen10:N870
# Gen10:N870:  Gen10:N869
# Gen10:N871:  Gen10:N869
# Gen10:N872:  Gen10:N871
# Gen10:N873:  Gen10:N874
# Gen10:N874:  Gen10:N873
# Gen10:N875:  Gen10:N876
# Gen10:N876:  Gen10:N875
# Gen10:N877:  Gen10:N878
# Gen10:N878:  Gen10:N877
# Gen10:N879:  Gen10:N878
# Gen10:N880:  Gen10:N878
# Gen10:N881:  Gen10:N882
# Gen10:N882:  Gen10:N881
# Gen10:N883:  Gen10:N881
# Gen10:N884:  Gen10:N881
# Gen10:N885:  Gen10:N886
# Gen10:N886:  Gen10:N885
# Gen10:N887:  Gen10:N888
# Gen10:N888:  Gen10:N847
# Gen10:N891:  Gen10:N892
# Gen10:N892:  Gen10:N891
# Gen10:N893:  Gen10:N889
# Gen10:N894:  Gen10:N889
# Gen10:N895:  Gen10:N893
# Gen10:N896:  Gen10:N895
# Gen10:N897:  Gen10:N898
# Gen10:N898:  Gen10:N897
# Gen10:N899:  Gen10:N897
# Gen10:N900:  Gen10:N898
# Gen10:N901:  Gen10:N911
# Gen10:N902:  Gen10:N911
# Gen10:N903:  Gen10:N901
# Gen10:N904:  Gen10:N903
# Gen10:N905:  Gen10:N906
# Gen10:N906:  Gen10:N905
# Gen10:N907:  Gen10:N908
# Gen10:N908:  Gen10:N907
# Gen10:N909:  Gen10:N899
# Gen10:N910:  Gen10:N898
# Gen10:N911:  Gen10:N901
# Gen10:N912:  Gen10:N911
# Gen10:N913:  Gen10:N914
# Gen10:N914:  Gen10:N913
# Gen10:N915:  Gen10:N919
# Gen10:N916:  Gen10:N918
# Gen10:N917:  Gen10:N918
# Gen10:N918:  Gen10:N916
# Gen10:N919:  Gen10:N915
# Gen10:N920:  Gen10:N918
# Gen10:N921:  Gen10:N922
# Gen10:N922:  Gen10:N921
# Gen10:N923:  Gen10:N924
# Gen10:N924:  Gen10:N923
# Gen10:N925:  Gen10:N926
# Gen10:N926:  Gen10:N925
# Gen10:N927:  Gen10:N928
# Gen10:N928:  Gen10:N927
# Gen10:N929:  Gen10:N930
# Gen10:N930:  Gen10:N929
# Gen10:N931:  Gen10:N930
# Gen10:N932:  Gen10:N930
# Gen10:N933:  Gen10:N934
# Gen10:N934:  Gen10:N933
# Gen10:N935:  Gen10:N933
# Gen10:N936:  Gen10:N935
# Gen10:N937:  Gen10:N938
# Gen10:N938:  Gen10:N937
# Gen10:N939:  Gen10:N938
# Gen10:N940:  Gen10:N939
# Gen10:N941:  Gen10:N942
# Gen10:N942:  Gen10:N941
# Gen10:N943:  Gen10:N944
# Gen10:N944:  Gen10:N943
# Gen10:N945:  Gen10:N946
# Gen10:N946:  Gen10:N945
# Gen10:N947:  Gen10:N952
# Gen10:N948:  Gen10:N946
# Gen10:N949:  Gen10:N946
# Gen10:N952:  Gen10:N947
# Gen10:N953:  Gen10:N954
# Gen10:N954:  Gen10:N953
# Gen10:N955:  Gen10:N956
# Gen10:N956:  Gen10:N955
# Gen10:N959:  Gen10:N960
# Gen10:N960:  Gen10:N959
# Gen10:N962:  Gen10:N759
# Gen10:N963:  Gen10:N964
# Gen10:N964:  Gen10:N963
# Gen10:N965:  Gen10:N961
# Gen10:N967:  Gen10:N968
# Gen10:N968:  Gen10:N967
# Gen10:N969:  Gen10:N970
# Gen10:N970:  Gen10:N969
# Gen10:N971:  Gen10:N970
# Gen10:N972:  Gen10:N970
# Gen10:N973:  Gen10:N965
# Gen10:N974:  Gen10:N970
# Gen10:N975:  Gen10:N976
# Gen10:N976:  Gen10:N975
# Gen10:N977:  Gen10:N986
# Gen10:N978:  Gen10:N977
# Gen10:N981:  Gen10:N982
# Gen10:N982:  Gen10:N981
# Gen10:N983:  Gen10:N984
# Gen10:N984:  Gen10:N983
# Gen10:N985:  Gen10:N986
# Gen10:N986:  Gen10:N961
# Gen10:N987:  Gen10:N986
# Gen10:N991:  Gen10:N992
# Gen10:N992:  Gen10:N991
# Gen10:N993:  Gen10:N994
# Gen10:N994:  Gen10:N993
# Gen10:N995:  Gen10:N911
# Gen10:N996:  Gen10:N995
# Gen10:N997:  Gen10:N998
# Gen10:N998:  Gen10:N997
# Gen10:N999:  Gen10:N1000
# Gen10:N1000:  Gen10:N999
# Gen10:N1001:  Gen10:N1002
# Gen10:N1002:  Gen10:N1001
# Gen10:N1003:  Gen10:N1001
# Gen10:N1004:  Gen10:N1001
# Gen10:N1005:  Gen10:N1006
# Gen10:N1006:  Gen10:N1005
# Gen10:N1007:  Gen10:N1008
# Gen10:N1008:  Gen10:N1007
# Gen10:N1011:  Gen10:N963
# Gen10:N1013:  Gen10:N1014
# Gen10:N1014:  Gen10:N1013
# Gen10:N1015:  Gen10:N1009
# Gen10:N1016:  Gen10:N1015
# Gen10:N1017:  Gen10:N1015
# Gen10:N1018:  Gen10:N1015
# Gen10:N1019:  Gen10:N1020
# Gen10:N1020:  Gen10:N1015
# Gen10:N1021:  Gen10:N1015
# Gen10:N1022:  Gen10:N1021
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# /tmp/ipykernel_3302156/2572107960.py:171: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   vars_all = vars_all.append(vars)
# 0.8690476190476188
# (0.0, 100.0)

# %%
vars_G2 
vars_G3
vars_all

plt.style.use("ggplot")
fig, ax = plt.subplots(figsize = (10,5))

vars_G1.pos.plot.kde(c = 'b', ax = ax)
vars_G2.pos.plot.kde(c = 'y', ax = ax, alpha = 0.2)
vars_G3.pos.plot.kde(c = 'y', ax = ax, alpha = 0.2)
vars_G4.pos.plot.kde(c = 'y', ax = ax, alpha = 0.2)
vars_G5.pos.plot.kde(c = 'y', ax = ax, alpha = 0.2)
vars_G6.pos.plot.kde(c = 'r', ax = ax)
vars_test.pos.plot.kde(c = 'g', ax = ax)

# vars_G7.pos.plot.kde(c = 'r', ax = ax)
# ax.legend(labels=['New genetic variations'], frameon=False)
plt.xlabel("Position in the sequence")
plt.ylabel("Number of variations")
ax.set_xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
vars_test
# Out:
#    ref tar pos
# 56   G   C  56
# 53   G   A  53
# 53   G   T  53
# 47   T   C  47
# 54   A   T  54
# ..  ..  ..  ..
# 49   G   C  49
# 47   T   A  47
# 44   G   T  44
# 52   A   G  52
# 46   T   A  46
#
# [484 rows x 3 columns]
